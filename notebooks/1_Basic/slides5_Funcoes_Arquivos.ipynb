# %% [markdown]
# # <font color = "blue" style="background-color: #E9F7E1;"> Funções e Arquivos</font>
#
# <ul><li><b>Funções</b></li>
#     <li><b><a href="#arquivos"  title="persistência de dados em memória secundária">Arquivos</a></b></li>
#     <li><b><a href="#pickle"   title="conservação de objetos em memória secundária">Pickle</a></b></li>
#     <li><b><a href="#anexo">Anexo - Biblioteca Padrão do Python</a></b></li></ul>

# %% [markdown]
# ## 1. Funções
#
# ### 1.1 Chamada de uma Função
# No contexto da programação, função é um conjunto de instruções que realiza uma computação. Quando você define uma função, você especifica o nome, parâmetro(s) e o conjunto de instruções. Posteriormente, pode-se "chamar" a função pelo seu nome e o argumento(s). A expressão em parênteses é chamada de argumento(s) da função na sua chamada, e de parâmetro(s) da função na sua declaração (definição). O argumento é um valor ou variável que passamos à função como entrada.

# %% [markdown]
# ### 1.2 Funções Nativas (incorporadas, *built-in*)
# O Python fornece várias funções internas (nativas, embarcadas) que são usadas sem que seja preciso definí-las. Os criadores do Python (Guido van Rossum e comunidade) escreveram várias funções para solucionar problemas comuns.
# A funções `max()` e `min()` nos dão o maior e o menor valores de uma sequência, respectivamente:

# %%
valores = (33,2,45,3,1,46,12)
print(valores)
print(max(valores), min(valores), len(valores))
# Out:
# (33, 2, 45, 3, 1, 46, 12)
# 46 1 7

# %% [markdown]
# ### Relação das [Funções Nativas](https://docs.python.org/3/library/functions.html)
# A - **abs()**, aiter(), all(), any(), anext(), **ascii()** <br>
# B - **bin()**, **bool()**, **breakpoint()**, bytearray(), bytes().
# C - callable(), **chr()**, classmethod(), compile(), **complex()**.   <br>
# D - delattr(), **dict()**, **dir()**, **divmod()**.  <br>
# E - **enumerate()**, **eval()**, exec().
# F - filter(), **float()**, format(), frozenset().
# G - getattr(), globals().
# H - hasattr(), hash(), **help()**, **hex()**.   <br>
# I - id(), **input()**, **int()**, isinstance(), issubclass(), iter().
# L - **len()**, **list()**, locals().
# M - map(), **max()**, memoryview(), **min()**.   <br>
# N - next().
# O - object(), **oct()**, **open()**, **ord()**.<br>
# P - **pow()**, **print()**, property().
# R - **range()**, repr(), reversed(), round().
# S - set(), setattr(), slice(), **sorted()**, staticmethod(), **str()**, **sum()**, **super()**.  <br>
# T - **tuple()**, **type()**.  <br>
# V - vars().
# Z - zip().
# _ - \_\_import\_\_()
#
# *Obs*.: Em negrito, as funções mais usuais.

# %% [markdown]
# ### 1.3 Funções de Conversão de Tipo
# O Python também fornece funções internas que convertem valores de um tipo de dados em outro. A função `int()` recebe qualquer valor e o converte em um inteiro, se for possível. Outras funções de conversão de tipo:
#
# |Função|Conversão|
# |:---: |:---|
# |`int()`|para número inteiro|
# |`float()`|para número real|
# |`complex()`|para número complexo|
# |`str()`|para string|
# |`bool()`|para booleano|

# %%
x = input("Digite algo:")   # sempre retorna uma 'string'
y = complex(x)
print(y+20, type(y))
# Out:
# Digite algo:33
# (53+0j) <class 'complex'>

# %%
print(bool(0), bool(40), complex(-1))
print(int('1292'))
print(int('2343a'))
# Out:
# False True (-1+0j)
# 1292
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21740/1083940365.py in <module>
#       1 print(bool(0), bool(40), complex(-1))
#       2 print(int('1292'))
# ----> 3 print(int('2343a'))
#
# ValueError: invalid literal for int() with base 10: '2343a'

# %% [markdown]
# ### 1.4 Funções Matemáticas
# As funções matemáticas do Python estão disponíveis num módulo (biblioteca) chamado `math`, e por isso, antes de usar suas funções matemáticas temos que importá-lo:
#
# `import math`
#
# Essa declaração cria um objeto do módulo chamado `math`. Se usarmos `print(math)` veremos algumas informações sobre ele:

# %%
import math
print(math,"\nNúmero de Neper:", math.e)
fm = dir(math)
for funcao in fm:
    print(funcao,end=', ')
# Out:
# <module 'math' (built-in)>
# Número de Neper: 2.718281828459045
# __doc__, __loader__, __name__, __package__, __spec__, acos, acosh, asin, asinh, atan, atan2, atanh, ceil, comb, copysign, cos, cosh, degrees, dist, e, erf, erfc, exp, expm1, fabs, factorial, floor, fmod, frexp, fsum, gamma, gcd, hypot, inf, isclose, isfinite, isinf, isnan, isqrt, lcm, ldexp, lgamma, log, log10, log1p, log2, modf, nan, nextafter, perm, pi, pow, prod, radians, remainder, sin, sinh, sqrt, tan, tanh, tau, trunc, ulp,

# %% [markdown]
# O objeto do módulo contém as funções e as variáveis definidas no módulo. Para acessar uma dessas funções, você deve especificar o nome do módulo e o nome da função, separados por um ponto. Esse formato é conhecido como **notação de ponto**. O valor da constante pi ($\pi$), com 15 dígitos de precisão, pode ser obtida por `math.pi`.
# Exemplo:

# %%
potencia_do_sinal, potencia_do_ruido = 1000, 0.001   # 1 kW, 1 mW
razao_abs = potencia_do_sinal / potencia_do_ruido
razao_db  = 10 * math.log10(razao_abs)
theta     = 0.7                                      # em radianos
modulo    = math.sqrt(math.sin(theta)**2 + math.cos(theta)**2)
print(f"Pot_sinal/Pot_ruido: {razao_abs} vezes, ou {razao_db:+.1f} db\nMódulo: {modulo}")
# Out:
# Pot_sinal/Pot_ruido: 1000000.0 vezes, ou +60.0 db
# Módulo: 1.0

# %% [markdown]
# ### 1.5 Geração de Números Aleatórios
# Os algoritmos disponíveis não são capazes de gerar números aleatórios mas apenas números pseudoaleatórios, e são assim denominados por serem gerados por uma computação determinística.
#
# O módulo `random` oferece funções que geram números pseudoaleatórios, tais como a função `random()` que retorna um número real (ponto flutuante, *`float`*) entre 0.0 e 1.0 (incluindo o limite inferior, 0.0, mas não
# o limite superior, 1.0). Todas as vezes que chamarmos essa função, teremos o próximo número de uma longa série de números pseudoaleatórios.
#
# Exemplo:

# %%
# import random
# import random as rnd
from random import random

for i in range(10):
    x = random()           # random.random()      # rnd.random()
    print(x, end=', ')
# Out:
# 0.12783139875412697, 0.9156791444858917, 0.9398854105455167, 0.8124884835021, 0.3778315612602283, 0.3622704564647583, 0.12015639163177905, 0.44614114760215073, 0.9449190462516482, 0.6064429200261486,

# %% [markdown]
# A função `random()` é apenas uma das funções do módulo **random** que geram números aleatórios. Outra
# função usual é a `randint()` que recebe dois parâmetros:  `'menor'` e `'maior'` e retorna um inteiro entre `'menor'` e `'maior'`, incluindo os limites.

# %%
# Aposta na Mega-Sena
from random import randint
aposta = []
dez = 0
while dez < 6:
    num = randint(1, 60)
    if num not in aposta:
        aposta.append(num)
        dez += 1
    # print(f'{randint(1, 60)}', end=' ')     # podem aparecer valores repetidos
print(aposta)
# Out:
# [7, 44, 41, 14, 45, 8]

# %% [markdown]
# Outra função do módulo `random` muito útil é a `choice()`, que escolhe aleatoriamente um elemento de uma sequência fornecida como argumento:

# %%
from random import choice

t = [10, 20, 30, 40, 50, 60]
for esc in range(1,11):
    print(f'Escolha {esc:2d}: {choice(t)}')
# Out:
# Escolha  1: 20
# Escolha  2: 60
# Escolha  3: 60
# Escolha  4: 30
# Escolha  5: 10
# Escolha  6: 20
# Escolha  7: 20
# Escolha  8: 50
# Escolha  9: 60
# Escolha 10: 60

# %% [markdown]
# O módulo `random` também disponibiliza funções para gerar valores aleatórios de acordo com funções de distribuição contínuas: gaussiana, exponencial, gamma e outras.

# %% [markdown]
# ### 1.6 Funções do Usuário
# Até agora, usamos apenas as funções do Python, mas também é possível adicionar novas funções. A definição de uma função pelo usuário começa pela especificação do nome da função, parâmetro(s) (se existir(em)) e o conjunto de comandos que serão executados quando a função for chamada.
#
# Sintaxe:
# ``` python
# def nome_funcao([parametro1[, parametro2, ...[, parametroN]]]):
#     comando (ou bloco de comandos)
# ```
# Uma vez definida, a função pode ser utilizada repetidas vezes ao longo do programa.
#
# **Exemplo**:

# %%
def refrao():
     print('Fica sempre um pouco de perfume\n' \
           'nas mãos que oferecem rosas\n'     \
           'nas mãos que sabem ser generosas')

# %% [markdown]
# A palavra-chave **`def`** indica a definição de uma função de usuário. O nome da função é `refrao`. As regras para nomes de funções são as mesmas usadas para nominar variáveis. Não se pode usar uma palavra-chave como nome de função, e deve-se evitar também uma variável e uma função com mesmos nomes.
#
# Os parênteses vazios após o nome da função indicam que essa função não usará argumentos ao ser chamada.
# A primeira linha da definição da função é chamada de **cabeçalho** da função, e o restante é o **corpo** da função. O cabeçalho é finalizado sempre com um caracter de dois pontos, `:`, e o corpo tem que estar
# indentado. Por convenção, a indentação é de quatro espaços em branco.
#
# Todos os elementos da linguagem Python são objetos, inclusives as funções de usuários.

# %%
print(refrao, type(refrao))
refrao()
# Out:
# <function refrao at 0x0000021BA5EE3A60> <class 'function'>
# Fica sempre um pouco de perfume
# nas mãos que oferecem rosas
# nas mãos que sabem ser generosas

# %% [markdown]
# ### 1.7 Fluxo de Execução
# Para garantir que a função seja definida antes de sua primeiro chamada, é preciso saber a ordem em que cada declaração é executada -- fluxo de execução.
#
# A execução sempre começa na primeira declaração do programa. Declarações são executadas uma por vez, na ordem de cima para baixo. Definições de função não alteram o fluxo da execução do programa, e lembre-se de que comandos dentro da função não são executados até que a função seja chamada.
#
# Uma chamada de função provoca um desvio no fluxo da execução. Em vez de ir para a próxima declaração, o fluxo de execução é desviado para o corpo da função, e depois de ter executado todos os comandos da função, o fluxo de execução volta para o ponto de onde havia sido desviado.

# %% [markdown]
# ### 1.8 Parâmetros e Argumentos
# Algumas das funções internas já usadas necessitavam de argumentos. Por exemplo, a função `math.sin()` precisa de um número como argumento, o ângulo (em radianos). Algumas funções requerem mais de um argumento: `math.pow()` recebe dois argumentos, a base e o expoente.
#
# Exemplo:

# %%
def mostra_duas_vezes(param):
    print(param)
    print(param)

# Observe que a função funciona com qq. tipo de dado passado como argumento
mostra_duas_vezes(5)
mostra_duas_vezes('Olá! ')
# Out:
# 5
# 5
# Olá!
# Olá!

# %% [markdown]
# ### 1.9 Funções e Subrotinas
# Alguns subprogramas, como as funções matemáticas, retornam resultados ao chamador da `função`; outros subprogramas, como `mostra_duas_vezes()`, executam uma ação mas não retornam um valor ao chamador. Elas são chamadas de `subrotinas` ou `funções vazias`.
#
# Quando se chama um subprograma do tipo `função`, espera-se um valor de retorno; por exemplo, podemos atribuir o retorno da função a uma variável ou usá-lo como parte de uma expressão:

# %%
x = math.cos(theta)
y = (math.sqrt(5) + 1) / 2
print(f'x={x} y={y}')
# Out:
# x=0.7648421872844885 y=1.618033988749895

# %% [markdown]
# Para retornar um resultado de uma função ao chamador, usa-se o comando **`return`** na função criada pelo usuário. Por exemplo, vamos criar uma função para calcular e retornar a soma de dois números.

# %%
def soma(x, y):                  # função de soma
    return x + y

print('33 + 54 =', soma(33, 54))
# Out:
# 33 + 54 = 87

# %% [markdown]
# Os parâmetros podem ter valores padrões, caso o usuário não queira especificar argumentos usuais nas chamadas às funções.
# Exemplo:

# %%
def familia(nome, sobrenome = "da Silva"):     # subrotina
    print(f'{nome} {sobrenome}')

familia("João")
familia("Tobias","Oliveira")
familia("Maria")
# Out:
# João da Silva
# Tobias Oliveira
# Maria da Silva

# %% [markdown]
# ### 1.10 Número Variável de Argumentos (Python 3)
# Na definição de uma função, os **parâmetros** são entidades nomeadas que especificam os **argumentos** que uma determinada função pode aceitar.
#
# Ao programar, você pode não estar ciente de todos os casos de uso possíveis de seu código e pode querer oferecer mais opções para futuros programadores que usem o seu módulo ou para usuários que interagem com o código. Podemos passar um **número variável de argumentos** ao chamar uma função, usando **\*args** e **\*\*kwargs** em nosso código.
#
# Vejamos uma típica função Python que usa dois argumentos:

# %%
def multiplicacao(x, y):       # dois argumentos nominados: x, y
    print (x * y)

multiplicacao(6, 9)
# Out:
# 54

# %% [markdown]
# E se, mais tarde, precisarmos multiplicar três números em vez de apenas dois? Se tentarmos adicionar um novo número à função, conforme mostrado abaixo, receberemos uma mensagem de erro.

# %%
multiplicacao(6, 9, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12592/120517173.py in <module>
# ----> 1 multiplicacao(6, 9, 3)
#
# TypeError: multiplicacao() takes 2 positional arguments but 3 were given

# %% [markdown]
# ### 1.10.1 Usando \*args
# Portanto, prevendo a possibilidade de se usar mais argumentos posteriormente, podemos usar **\*args** como parâmetro da função `multiplicacao()`, da seguinte forma:

# %%
def multiplicacao(*args):        # lista de argumentos não nominados
    resultado = 1
    for argumento in args:
        resultado *= argumento
    print(resultado)

multiplicacao(6, 9, 3)
multiplicacao(6, 9, 3, 2, 0.5)
# Out:
# 162
# 162.0

# %% [markdown]
# Como usamos **\*args** para enviar uma lista de argumentos de comprimento variável para função `multiplicacao()`, fomos capazes de passar tantos argumentos quantos desejamos nas chamadas à função, ou seja, foi possível a criação de um código mais flexível que aceita uma quantidade variada de argumentos não nominados na função em questão.

# %% [markdown]
# ### 1.10.2 Usando \*\*kwargs
# A forma que usa asterisco duplo, **\*\*kwargs** é usada para passar um dicionário de argumentos de comprimento variável nominados para uma função. Os dois asteriscos (`**`) são os elementos importantes na sintaxe, visto que a palavra **kwargs** é usada convencionalmente, embora não seja imposta pela linguagem.
#
# Assim como **\*args**, **\*\*kwargs** pode aceitar quantos argumentos você quiser. No entanto, **\*\*kwargs** difere de **\*args** porque você precisa atribuir os valores dos argumentos aos respectivos nomes dos parâmetros.
#
# Vamos usar uma função curta para mostrar os argumentos **\*\*kwargs** passados à função:

# %%
def mostra_argumentos(**kwargs):    # dicionário de argumentos nominados
    print(kwargs)
    
mostra_argumentos(arg1="Maria", arg2=242.7, arg3=False)
# Out:
# {'arg1': 'Maria', 'arg2': 242.7, 'arg3': False}

# %% [markdown]
# **Obs**.: Dependendo da versão do Python 3 que você está usando, o tipo de dados dicionário pode estar não ordenado. No Python 3.6 e superior, você receberá os pares de **valores-chave** em ordem, mas nas versões anteriores, os pares serão exibidos em uma ordem aleatória.

# %% [markdown]
# Vamos criar outra função curta para mostrar como usar **\*\*kwargs**, uma função para saudar pessoas cujos nomes (argumentos) são passados como dicionário de nomes:

# %%
def mostra_nomes(**kwargs):
    for chave, valor in kwargs.items():
        print("O valor de '{}' é {}".format(chave, valor))

mostra_nomes(nome1="João", nome2="Maria")
# Out:
# O valor de 'nome1' é João
# O valor de 'nome2' é Maria

# %% [markdown]
# Vamos agora passar argumentos adicionais à função para mostrar que **\*\*kwargs** aceita quantos argumentos você quiser incluir:

# %%
mostra_nomes(nome1="João", 
             nome2="Maria",
             nome3="José",
             nome4="Davi",
             nome5="Matheus")
# Out:
# O valor de 'nome1' é João
# O valor de 'nome2' é Maria
# O valor de 'nome3' é José
# O valor de 'nome4' é Davi
# O valor de 'nome5' é Matheus

# %% [markdown]
# Usar **\*\*kwargs** nos fornece flexibilidade para usar uma quantidade variável de argumentos nominados em nosso programa, ou seja, não é preciso saber quantos argumentos serão passados à uma função, durante a sua declaração.
#
# ### 1.10.3 Argumentos Ordenados
# Ao indicar os argumentos na declaração ou chamada de uma função, é preciso que eles apareçam em uma ordem específica:
#
# <ol><li>Argumentos posicionais formais.</li>
#     <li><strong>*args</strong>.</li>
#     <li>Argumentos nominados.</li>
#     <li><strong>**kwargs.</strong></li></ol>
#
# Vejamos um exemplo de função com parâmetros posicionais explícitos junto com **\*args** e **\*\*kwargs**:
# ```python
# def exemplo1(arg1, arg2, *args, **kwargs):
# ...
# ```
# Usando parâmetros posicionais com parâmetros nomeados, além de **\*args** e **\*\*kwargs**, teríamos:
# ```python
# def exemplo2(arg1, arg2, *args, kw1="Maria", kw2=33.21, **kwargs):
# ...
# ```
# É importante manter a ordem dos argumentos em mente ao criar funções para evitar erros de sintaxe em seu código Python.
#
# ### 1.10.4 Usando **\*args** e **\*\*kwargs** nas Chamadas de Funções
# Vamos ver um exemplo usando  **\*args**:

# %%
def exemplo3(arg1, arg2, arg3):
    print("arg1: ", arg1, ", arg2: ", arg2, ", arg3: ", arg3, sep='')

argumentos = ("Maria", "João", 33.21)       # tupla de argumentos a serem usados na função 'exemplo3'
exemplo3(*argumentos)
outros = [3.4, True, 'Olá!']
exemplo3(*outros)
# Out:
# arg1: Maria, arg2: João, arg3: 33.21
# arg1: 3.4, arg2: True, arg3: Olá!

# %% [markdown]
# Da mesma forma, os argumentos **\*\*kwargs**  podem ser usados para chamar uma função. Vamos configurar uma variável igual a um dicionário com 3 pares de valores-chave (usaremos **kwargs** aqui, mas pode ser chamado como você quiser) e passá-lo para uma função com três argumentos:

# %%
kwargs = {"arg1": "Maria", "arg2": "José", "arg3": "Pedro"}
exemplo3(**kwargs)
# Out:
# arg1: Maria, arg2: José, arg3: Pedro

# %% [markdown]
# **Concluindo**: Podemos usar a sintaxe especial de **\*args** e **\*\*kwargs** na definição de uma função para passar um número variável de argumentos à função.
# A criação de funções que aceitam **\*args** e **\*\*kwargs** é melhor usada em situações em que você espera que o número de entradas na lista de argumentos permaneça relativamente pequeno.
# Fonte: https://www.digitalocean.com/community/tutorials/how-to-use-args-and-kwargs-in-python-3

# %% [markdown]
# ### Exercício
# 1. (Questão de concurso) Preencha as lacunas no código abaixo (L1 até L10), de forma a obter um programa que recebe uma string contendo exclusivamente palavras separadas por espaços em branco e determina a palavra mais frequente e sua frequência relativa de ocorrência de texto.
# Por exemplo, para "figurinha no pacote de figurinha" a saída do programa deve ser:
# palavra: figurinha - freq. rel.: 0.4
#
# ``` python
# def separa (texto):
#     L = L1
#     p = ''
#     for c in texto:
#         if c == ' ':
#             L.append(p)
#             p = ''
#         else:
#             p += c
#     L2
#     return L
#
# def maxfreq (texto):
#     L = L3
#     pf = []
#     f = L4
#     for p in L:
#         L5
#             pf.append(p)
#             f.append(1)
#         L6
#             for i in range(len(pf)):
#                 if p == pf[i]:
#                     L7
#     maxpf = ''
#     maxf = 0
#     for i in range(len(pf)):
#         if f[i] > maxf:
#             L8
#             L9
#     return L10
#
# def main ():
#     texto = input('Digite as palavras: ')
#     p, f = maxfreq(texto)
#     print ('palavra:', p, 'freq. rel.:', f)
#
# main()
# ```
#
# Para cada um dos itens a seguir, correspondendo às lacunas no código acima, assinale a única resposta que torna o programa acima correto.
#
# L1: A. [texto] B. ′′ C. texto D. 0 E. []
# L2: A. L+=1 B. L+=c C. L=[L,p] D. L=[L] E. L.append(p)
# L3: A. [separa(texto)] B. texto[i] C. texto  D. separa(texto) E. []
# L4: A. ′′  B. [] C. 0  D. [0]  E. L
# L5: A. if p[i] == pf[i]:   B. while p in pf:  C. if p != f:  D. if p != pf:  E. if not p in pf:
# L6: A. else:  B. if f == 0:  C. elif p not in pf:   D. if not f in pf:  E. if pf[i] == f[i]
# L7: A. f[i] += 1  B. f.append(f[i]+1)  C. f[i] = 2   D. pf[i] = f[i]   E. pf.append(f)
# L8: A. maxf = f[i]   B. maxf = 0   C. f[len(f)-1]   D. maxf = len(pf[i])  E. maxf = i
# L9: A. maxpf = separa(pf[i])[1]  B. maxpf = str(maxf)  C. maxpf = pf[i]   D. maxpf = ′′
#  E. maxpf = separa(texto)[i]
# L10: A. maxf, len(L)   B. maxpf, maxf  C. pf, f  D. maxf/len(pf), maxpf  E. maxpf, maxf/len(L)
#
# Gabarito: https://estudar.com.vc/conceitos/exercicios-de-prova-strings/exercicio-3-programa-com-strings-prova

# %% [markdown]
# ## <a id="arquivos">2. Arquivos</a>
#
# A partir deste instante começamos a trabalhar com a **Memória Secundária** (ou arquivos) para persistir as informações processadas.
#
# Vamos primeiramente ver a leitura e a escrita de arquivos de texto, como aqueles criados por meio de um editor de texto, por exemplo, **notepad**.
#
# ### 2.1 Abrindo um Arquivo
# Quando queremos ler ou escrever um arquivo, primeiro temos que abrí-lo para que o sistema operacional providencie o acesso aos dados do arquivo armazenado no dispositivo de memória secundária. No exemplo seguinte, vamos abrir o arquivo chamado 'caixa.txt' com a opção de anexar novas informações textuais ao arquivo, ou seja, o modo de abertura será 'at', onde 'a' é para anexação de dados e 't' indica dados do tipo textual.
#
# A função `open()` e demais funções relacionadas fazem parte da <a href="#anexo">biblioteca padrão do Python</a> (vem embutida na distribuição do Python, e é bem ampla, oferecendo uma variedade de recursos).
#
# Sempre que seu código abrir um arquivo para leitura ou gravação, você deve tomar cuidado para que o arquivo seja fechado ao terminar de usá-lo, para que seus dados não fiquem vulneráveis a modificações. Python fornece um gerenciador de contexto `open`, que é projetado para garantir que um arquivo seja fechado mesmo no caso de seu código gerar um erro.
#
# Ajuda mostrada pelo comando: ` >>> help(open)`
# >**`open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)`**
#    Abre o arquivo e retorna um descritor de fluxo (*stream*). Lança um OSError em caso de falha.
#
# > **'file'** ou é um texto ou uma string de bytes que fornece o nome (e o caminho se o arquivo não estiver no diretório de trabalho atual) do arquivo a ser aberto ou um descritor de arquivo do tipo inteiro. (Se um descritor de arquivo é fornecido, ele é fechado quando o objeto de E/S retornado é fechado, a menos que **'closefd'** seja definido como *False*).
#
# > **'mode'** é uma string opcional que especifica o modo em que o arquivo é aberto. O padrão é 'r', o que significa aberto para leitura em modo texto. Outros valores comuns são 'w' para escrita (truncar o arquivo se já existe), 'x' para criar e gravar em um novo arquivo, e 'a' para anexar (que em alguns sistemas Unix, significa que todas as gravações serão anexadas ao final do arquivo, independentemente da posição de busca atual). No modo de texto, se a codificação não for especificada, a codificação usada é dependente da plataforma: locale.getpreferredencoding (False) é chamado para obter a codificação local atual. (Para ler e escrever bytes brutos use o modo binário e não especifique a codificação). Os modos disponíveis são:
#
# Especificar `mode = 'w'` indica que iremos gravar no arquivo -- se o arquivo já tiver algum conteúdo, esse conteúdo será apagado antes de ser gravado. A seguir estão os "modos" disponíveis de abertura de um arquivo:
#
# |Caracter | Significado |
# | :-----: | :---------- |
# |    'r'  | aberto para leitura (padrão) |
# |    'w'  | abre para escrita, truncando o arquivo caso já exista |
# |    'x'  | cria um novo arquivo e o abre para escrita |
# |    'a'  | aberto para escrita, acrescentado ao final do arquivo, se existir |
# |    'b'  | modo binário |
# |    't'  | modo de texto (padrão) |
# |    '+'  | abre um arquivo em disco para atualização (leitura e gravação) |
#
#
# O modo padrão é 'rt' (aberto para leitura de texto). Para acesso binário aleatório, o modo 'w+b' abre e trunca o arquivo para 0 bytes, enquanto 'r+b' abre o arquivo sem truncamento. O modo 'x' implica 'w' e gera um `FileExistsError` se o arquivo já existe.
#
# Por padrão, os arquivos do tipo **texto** utilizam a especificação de decodificação/codificação unicode (utf-8). Ou seja, quando você lê dados de arquivos com `mode = 'r'`, o Python decodificará automaticamente os dados binários que foram armazenados de acordo com o código **utf-8**, que converte os dados binários em texto escrito armazenado como uma string. Da mesma forma, gravar uma string num arquivo nos modos `'w', 'a', 'x'` ou `'+'` presumirá que a string será codificada em uma representação binária (que é necessária para ser armazenada num arquivo) de acordo com o esquema de codificação **utf-8**.
#
# Podemos forçar o Python a ler e escrever estritamente em termos de dados binários, adicionando um `'b'` aos modos: `'rb', 'wb', 'ab', 'xb', '+b'`. Se você estiver salvando uma matriz NumPy, vc deve abrir um arquivo nos modos `'wb'` ou `'xb'` para gravar dados binários; obviamente, não estamos salvando texto quando salvamos uma matriz NumPy de números.
#
# #### Criando um Arquivo Texto

# %%
# Demonstração do uso do gerenciador de contexto `open`
# criando um objeto caminho (path) apontando para o diretório corrente
from pathlib import Path

# vamos escrever no arquivo chamado 'arq1.txt', localizado no diretório atual
caminho_do_arq = Path ('.\\arq1.txt')
with open(caminho_do_arq, mode="w") as arq:
    # O espaço recuado entra no 'contexto' do arquivo aberto.
    # Saindo do espaço indentado existe o contexto do arquivo aberto, forçando
    # o arquivo a ser fechado. Isso é garantido mesmo se nosso código causar um erro
    # dentro deste bloco recuado
    arq.write('Esta é uma linha.\nEsta é uma segunda linha.\nEsta é a terceira linha.')
# O arquivo é fechado automaticamente daqui pra frente.

# %% [markdown]
# #### Informações Sobre o Arquivo

# %%
for narq in ['arq1','mbox']:
    arq = open(narq+'.txt','at')   # open retorna um handler (alça de manipulação do arquivo)
    print(arq)
    print("Nome do arquivo  : ", arq.name)
    print("Fechado          : ", arq.closed)
    print("Modo de abertura : ", arq.mode, "\n")
    arq.close()
# Out:
# <_io.TextIOWrapper name='arq1.txt' mode='at' encoding='cp1252'>
# Nome do arquivo  :  arq1.txt
# Fechado          :  False
# Modo de abertura :  at
#
# <_io.TextIOWrapper name='mbox.txt' mode='at' encoding='cp1252'>
# Nome do arquivo  :  mbox.txt
# Fechado          :  False
# Modo de abertura :  at

# %% [markdown]
# ### 2.2 Arquivos Textuais
# Um arquivo de texto pode ser pensado como uma sequência de linhas, assim como uma string em Python pode ser pensada como uma sequência de caracteres. Por exemplo, essa é uma amostra de um arquivo de texto que grava a atividade de *emails* de vários inivíduos em um projeto *open source* em desenvolvimento...
#
# > From stephen.marquard@uct.ac.za Sat Jan 5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Date: Sat, 5 Jan 2008 09:12:18 -0500
# To: source@collab.sakaiproject.org
# From: stephen.marquard@uct.ac.za
# Subject: [sakai] svn commit: r39772 - content/branches/
# Details: http://source.sakaiproject.org/viewsvn/?view=rev&rev=39772
# ...
#
# Todo o arquivo de interações de email está disponível em www.py4e.com/code3/mbox.txt e uma versão reduzida do arquivo está disponível em www.py4e.com/code3/mbox-short.txt.
#
# Eles estão em um formato padrão para um arquivo com várias mensagens de email. As linhas que começam com **"From"** separam as mensagens, e as linhas que começam com "From:" fazem parte delas. Para mais informações sobre o
# formato **mbox**, consulte https://en.wikipedia.org/wiki/Mbox.
#
# Para quebrar o arquivo em linhas, tem um caracter especial que representa o "fim da linha", comumente chamado de *newLine*.
# Em Python, representamos esse caracter pela constante string `'\n'`. Mesmo que pareçam ser dois caracteres, é na verdade um só. Quando olhamos para a variável inserindo "algo" no interpretador, ele nos mostra o '\n' na string, mas quando usamos `print()` para mostrá-la, vemos a string quebrada em duas linhas pelo uso do caracter *newline*. Este caractere divide o conteúdo do arquivo em linhas.

# %%
algo = 'Olá\nmundo!'
algo
# Out:
# 'Olá\nmundo!'

# %%
print(algo)
algo = '1\n2'
print(algo)
print(len(algo))
# Out:
# Olá
# mundo!
# 1
# 2
# 3

# %% [markdown]
# ### 2.3 Lendo Arquivos Textuais
# Depois de aberto o arquivo com a função `open()`, temos uma alça para manipular o conteúdo do arquivo em questão. Para ler o conteúdo do arquivo, podemos fazê-lo por caracter (um tanto quanto demorado) ou por linha (mais ágil). O exemplo seguinte mostra a leitura por linha:

# %%
# ajuste o caminho do arquivo baixado, na variável 'caminho'
caminho = 'dat/'
arq = open(caminho+'mbox-short.txt')     # open() retorna uma alça (handler) para manipulação de dados do/pro arquivo
linhas = 0
for linha in arq:                        # a iteração de linhas provoca a leitura dos dados no arquivo
    linhas += 1
print('Qtde de linhas no arquivo de emails:', linhas)
arq.close()
# Out:
# Qtde de linhas no arquivo de emails: 1910

# %% [markdown]
# O método **`close()`** de um objeto arquivo libera todas as informações não gravadas e fecha o objeto arquivo, após o que nenhuma outra gravação pode ser feita.
#
# O fechamento dos arquivos pode se dar de forma automática se usarmos `try/finallly`:
# 1. ``` python
# arq = open('entrada.txt')
# try:
#      # processamento do arquivo
# finally:
#      arq.close()
# ```
# 2. ``` python
# with open('entrada.txt') as arq:
#     # processamento do arquivo
# ```
#
# A instrução `with` cuida automaticamente do fechamento do arquivo quando o bloco `with` é encerrado, e mesmo em casos de erro. Recomenda-se o uso da declaração `with`, tanto quanto possível, pois ela permite um código mais limpo e facilita a manipulação de erros inesperados.
#
# Para mais detalhes sobre manipulação de arquivos, visite https://www.codigofluente.com.br/aula-20-python-biblioteca-padrao-modulo-io/.

# %%
# demonstração do uso do método `read` do objeto 'file'
with open(caminho_do_arq, mode="r") as arq:
    # lê o conteúdo todo do arquivo numa string
    conteudo = arq.read()
print(conteudo)
# Out:
# Esta é uma linha.
# Esta é uma segunda linha.
# Esta é a terceira linha.

# %% [markdown]
# Se o tamanho do arquivo é relativamente pequeno comparado ao da memória principal, então podemos ler o arquivo todo em uma string usando o método `read()` do identificador de arquivo, como mostra o exemplo seguinte:

# %%
arq = open(caminho+'mbox-short.txt')
conteudo = arq.read()                       # armazena todos os caracteres do arquivo na var. 'conteudo'
print('Qtde de caracteres:', len(conteudo))
print(conteudo[:50])
if arq.closed == False:
    arq.close()
# Out:
# Qtde de caracteres: 94626
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:1

# %% [markdown]
# Quando o arquivo é lido dessa forma, todos os caracteres, incluindo os caracteres de novas linhas (*newline*) formam uma grande string armazenada na variável `conteudo`. É uma boa ideia armazenar a saída de `read()` numa variável porque cada chamada de `read()` faz uso do recurso computacional.
#
# #### Métodos do Objeto `file`:
#
# * **read()**: Lê todo o conteúdo do arquivo como uma string ou como bytes (dependendo do modo de abertura)
# * **readline()**: Lê a próxima linha de texto do arquivo, incluindo o caractere final '\n'
# * **readlines()**: Lê as linhas de texto do arquivo, armazenando cada linha como uma string em uma lista.
# * **write(x)**: Escreve a string 'x' no arquivo.
# * **writelines(x)**: Dado um iterável de strings, trata cada string como uma linha de texto a ser gravada no arquivo (o inverso de `readlines()`)
#
# Além disso, é importante observar que o objeto `file` pode ser iterado e que cada iteração retornará uma linha individual de texto do arquivo. Esta é a melhor maneira de ler um arquivo inteiro, linha a linha.

# %% [markdown]
# ### 2.4 Busca em um Arquivo
# Quando se está procurando por dados em um arquivo, é muito comum percorrer o arquivo, ignorando a maioria das linhas e apenas processando as que combinam com uma condição particular. Podemos ajuntar a leitura do arquivo com os métodos de strings para construir um mecanismo de busca.
#
# Por exemplo, se quisermos ler um arquivo e mostrar apenas as linhas que começam com o prefixo "From:", podemos usar o método `startswith()` para selecionar apenas as linhas que possuem o prefixo desejado. Usamos também o método `rstrip()` para eliminar os espaços em branco à esquerda ou direita da string:

# %%
arq = open(caminho+'mbox-short.txt')
for linha in arq:
    if linha.startswith('From:'):
        print(linha.rstrip())

# %% [markdown]
# Vamos usar o método `find()` de strings para procurar por uma ocorrência de uma string dentro de outra e retornar a posição dela ou -1 se não for encontrada. Em particular, vamos mostrar somente as linhas que contém a string “@uct.ac.za” (isto é, emails oriundos da Universidade de Cape Town, na África do Sul):

# %%
arq = open(caminho+'mbox-short.txt')
for linha in arq:
    if linha.startswith('From:'):
        if linha.find('@uct.ac.za') == -1: continue
        print(linha.rstrip())
# Out:
# From: stephen.marquard@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za

# %% [markdown]
# No script anterior usamos a forma contraída da sentença `if` quando colocamos o `continue` na mesma linha do `if`. Essa forma funciona do mesmo jeito que se o `continue` estivesse na próxima linha e indentado.

# %% [markdown]
# ### 2.5 Qual Arquivo?
#
# #### Usuário Escolhe o Arquivo
# Para não ter quer editar o código Python toda vez que quisermos processar um arquivo diferente, podemos solicitar ao usuário a entrada do nome do arquivo a ser processado, cada vez que o programa for executado.

# %%
nomearq = input('Entre nome do arquivo (sem a extensão): ')
arq = open(caminho+nomearq+'.txt')
contagem = 0
for linha in arq:
    if linha.startswith('Subject:'):
        contagem += 1
print(f"Tem {contagem} linhas com 'Subject' em {nomearq}.txt")
# Out:
# Entre nome do arquivo (sem a extensão): mbox-short
# Tem 27 linhas com 'subject' em mbox-short.txt

# %% [markdown]
# #### Procurando Arquivos
# Existem muitos casos em que podemos querer iterar o conteúdo de uma lista de arquivos... Vamos construir manualmente essa lista de arquivos:

# %%
arquivos = ['dat/arq1.txt', 'dat/arq2.txt', 'dat/arq3.txt', 'dat/arq4.txt']

# %% [markdown]
# No entanto, isso é extremamente tedioso e sujeito a erros, seja digitando incorretamente o nome de um arquivo ou esquecendo-se de um ou outro arquivo. A maneira certa de se construir essa lista de arquivos é **agrupando** arquivos. Um *glob* é um conjunto de nomes de arquivos que correspondem a um dado padrão. Para globalizar arquivos, usamos caracteres curinga especiais que irão corresponder a todos os arquivos com uma determinada parte de um nome de arquivo. Nesse caso, o asterisco `*` será o caractere curinga que mais usaremos -- ele corresponde a qualquer caractere. Abaixo, vemos alguns *globs* e os tipos de padrões aos quais eles corresponderão:

# %% [markdown]
# ```python
# # corresponde a qualquer coisa que comece com `arq` e termine com `.txt` como
# # arq1.txt, arq_tmp.txt, arq.txt, arq12345.txt, ...
# arq*.txt
#
# # corresponde a todos os arquivos '.txt' no diretório 'dat'
# dat/*.txt
#
# # corresponde a qualquer nome de arquivo
# *
#
# # corresponde a todos os arquivos de imagem png
# *.png
#
# # corresponde a qualquer coisa que contenha 'teste' como parte de seu nome de arquivo
# *teste*
#
# # corresponde a todos os arquivos '.py' que contêm 'numero'
# *numero*.py
# ```

# %% [markdown]
# O módulo `pathlib` fornece funcionalidade conveniente para agrupamento de arquivos (*globbing*). Assim que tivermos um objeto `Path`, podemos simplesmente chamar `glob()` nele e passar uma string. Isso retornará um gerador que produzirá cada um dos arquivos agrupados.

# %%
# agrupa todos os arquivos de texto no diretório atual
# que começa com 'arq' e termina com '.txt'
dir_raiz = Path('.')
arqs = dir_raiz.glob('arq*.txt')              # isso produz um gerador
arqs
# Out:
# <generator object Path.glob at 0x000002CD5CCE6BA0>

# %%
# obter uma lista ordenada dos caminhos agrupados
sorted(arqs)
# Out:
# [WindowsPath('arq1.txt'), WindowsPath('arqteste.txt')]

# %%
# iterando sobre o gerador diretamente
for arquivo in dir_raiz.glob('arq*.txt'):
    with open(arquivo, 'r') as f:
        # faz algum processamento
        string = f.readlines()
        print(string)
# Out:
# ['Esta é uma linha.\n', 'Esta é uma segunda linha.\n', 'Esta é a terceira linha.']
# ['Arquivo teste para tratamento de exceção!!']

# %% [markdown]
# <a style="color:red"><b>Exercício</b></a>:
#
# Escreva um padrão *glob* para cada um dos seguintes agrupamentos:
#
# - Todos os arquivos '.txt' do diretório './arqs'.
# - Todos os arquivos que contêm 'ifg' como parte de seu nome.
# - Todos os arquivos que começam com 'dados'.
# - Todos os arquivos que começam com a letra 'q', contém um 'w' e terminam com uma extensão '.npy'.

# %% [markdown]
# O caractere `*` não é o único padrão disponível. Às vezes, pode ser útil combinar certos subconjuntos de caracteres. Por exemplo, podemos querer apenas combinar nomes de arquivo que começam com um dígito numérico. Com o `*` curinga sozinho, isso não é possível. Para combinar um subconjunto de caracteres, podemos usar colchetes: `[abc]*` corresponderá a qualquer coisa que comece com `'a', 'b'` ou `'c'` e nada mais. Também podemos usar um hífen `'-'` dentro dos colchetes para agrupar faixa de caracteres. Por exemplo:
#
# ```python
# # corresponde a qualquer arquivo texto que comece com um dígito decimal
# [0-9]*.txt
#
# # corresponde a qualquer arquivo que tenha uma vogal em seu nome
# *[aeiou]*
#
# # corresponde a qualquer arquivo que comece com uma letra minúscula
# [a-z]*
# ```

# %% [markdown]
# <a style="color:red"><b>Exercício</b></a>:
#
# Escreva um padrão *glob* para cada um dos seguintes agrupamentos:
#
# - Todos os arquivos com um dígito octal ímpar em seu nome
# - Todos os arquivos '.txt' que contêm as letras 'q' ou 'z'

# %% [markdown]
# ### 2.6 Cuidando dos Erros Previsíveis
#  O que ocorre se o usuário não digitar um nome válido de arquivo no script anterior?

# %%
nomearq = input('Entre nome do arquivo (sem a extensão): ')
arq = open(caminho+nomearq+'.txt')
contagem = 0
for linha in arq:
    if linha.startswith('Subject:'):
        contagem += 1
print(f"Tem {contagem} linhas com 'Subject' em {nomearq}.txt")
# Out:
# Entre nome do arquivo (sem a extensão): kdjfls
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-88-71a190077860> in <module>
#       1 nomearq = input('Entre nome do arquivo (sem a extensão): ')
# ----> 2 arq = open(caminho+nomearq+'.txt')
#       3 contagem = 0
#       4 for linha in arq:
#       5     if linha.startswith('Subject:'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dat/kdjfls.txt'

# %% [markdown]
# Então, agora que vimos uma possível falha no programa, podemos corrigi-la usando a estrutura
# `try/except`:

# %%
nomearq = input('Entre nome do arquivo (sem a extensão): ')
try:
    arq = open(caminho+nomearq+'.txt')
except:
    print(f'Erro: Arquivo [{nomearq}.txt] não pode ser aberto!')
else:
    contagem = 0
    for linha in arq:
        if linha.startswith('Subject:'):
            contagem += 1
    print(f"Tem {contagem} linhas com 'Subject' em {nomearq}.txt")
# Out:
# Entre nome do arquivo (sem a extensão): fsdfs
# Erro: Arquivo [fsdfs.txt] não pode ser aberto!

# %% [markdown]
# ### 2.7 Gravando em Arquivos Textuais
# Para gravar dados em um arquivo é preciso abri-lo no modo de escrita, usando o parâmetro `mode = 'w'`:

# %%
arq = open(caminho+'saida.txt', 'w')
print(arq)
# Out:
# <_io.TextIOWrapper name='dat/saida.txt' mode='w' encoding='cp1252'>

# %% [markdown]
# Se o arquivo já existir, abri-lo no modo de gravação provocará o apagamento dos dados antigos e
# inicia a gravação a partir do zero, por isso tome cuidado! Se o arquivo não existir, um novo será
# criado.
# O método `write()` do objeto arquivo escreve dados no arquivo, retornando o número de caracteres gravados. O modo de gravação padrão é **texto** para escrever e ler strings.

# %%
linha1 = "Bem-aventurados os pobres de espírito, porque deles é o Reino dos céus. (Mt.5:3)\n"
arq.write(linha1)
# Out:
# 81

# %% [markdown]
# O arquivo mantém o controle de onde está o ponteiro de inserção de dados, logo, ao chamar `write()` novamente, ele adicionará os novos dados ao final. Devemos nos certificar de gerenciar as extremidades das linhas à medida que escrevemos no arquivo inserindo explicitamente o caracter *newline* quando terminar uma linha. A instrução `print()` anexa automaticamente uma nova linha, mas o método `write()` não adiciona a nova linha automaticamente.

# %%
linha2 = "Convém que vivamos de forma mais simples...\n"
arq.write(linha2)
arq.close()

# %%
# Visualizando o conteúdo do arquivo gravado
arq = open(caminho+'saida.txt')
print(arq.read())
arq.close()
# Out:
# Bem-aventurados os pobres de espírito, porque deles é o Reino dos céus. (Mt.5:3)
# Convém que vivamos de forma mais simples...

# %% [markdown]
# ### 2.8 Arquivos Binários
# Para gravar dados em um arquivo binário é preciso abri-lo no modo de escrita, usando o parâmetro `mode = 'wb'` ou `'xb'`:

# %%
# salvando um vetor NumPy (arranjo) no arquivo 'vetor.npy'
import numpy as np
x = np.array([1, 2, 3])
with open("vetor.npy", mode="wb") as f:
    np.save(f, x)

# %%
# carregando um vetor NumPy (arranjo) salvo no arquivo 'vetor.npy'
with open("vetor.npy", mode="rb") as f:
    y = np.load(f)
print(y)
# Out:
# [1 2 3]

# %% [markdown]
# <a style="color:red"><b>Exercícios</b></a>:
# 1. Escreva um programa que leia um arquivo e mostre o conteúdo (linha a linha), completamente em caixa alta (em letras maiúsculas). <br><br>
# 2. Escreva um programa que solicite o nome de um arquivo, e depois o leia e procure por linhas da forma: 'X-DSPAM-Confidence: 0.8475'. Quando encontrar uma linha que inicie com "X-DSPAM-Confidence:", separe o número de ponto flutuante que aparece no final da linha. Conte essas linhas e então compute o total de valores de Confiança de Spam. Quando chegar no fim do arquivo, mostre a média de Confiança de Spam. Teste seu programa com os arquivos mbox.txt e mbox-short.txt
# > Digite o nome de um arquivo: mbox.txt
# > Média de confiança de spam: 0.894128046745  <br><br>
# > Digite o nome de um arquivo: mbox-short.txt
# > Média de confiança de spam: 0.750718518519

# %% [markdown]
# ## <a id="pickle">3. Pickle</a>
#
# <img src= "img/pickles.jpg" width=300>
# Queremos evitar situações desagradáveis, como a perda de dados, calculados em seu programa Python. Então, vamos mostrar como salvar seus dados de maneira fácil, de modo que seu programa possa reler-los posteriormente. Vamos 'conservar' (*pickling*) os dados, para que nada se perca.
#
# Python oferece um módulo para essa finalidade, chamado `pickle`. Com os algoritmos do módulo **pickle** podemos serializar e deserializar estruturas de objetos Python. 'Conservar' (*unpickling*) é o processo de converter uma hierarquia de objetos Python num fluxo de bytes, e 'desconservar' (*pickling*) é a operação inversa, isto é, o fluxo de bytes é convertido novamente em uma hierarquia de objetos Python. O que chamamos de conservação é também conhecido como 'serialização' ou 'achatamento' de uma estrutura de dados.
#
# Um objeto pode ser serializado com o método de despejo (*dump*) do módulo `pickle`:
#
# ```python
# pickle.dump(obj, arquivo[, protocolo, *, fix_imports=True])
# ```
# `dump()` cria uma representação serializada de `obj` para abrir um arquivo do objeto. O argumento facultativo `protocolo`  diz ao serializador para usar o protocolo dado:
#
# * Protocolo versão 0 é o original (antes da Python3) protocolo legível (ASCII) e é compatível com versões anteriores do Python.
# * Protocolo versão 1 é o antigo formato binário que também é compatível com versões anteriores do Python.
# * Protocolo versão 2 foi introduzido em Python 2.3. Ele oferece muito mais conservação eficiente de classes de estilo novos.
# * Protocolo versão 3 foi introduzido em Python 3.0. Ele tem suporte explícito para bytes e não pode ser deserializar (*unpickled*) pelo módulo pickles do Python 2.x. É o protocolo recomendado para Python 3.x.
#
# O protocolo padrão de Python3 é a versão 3.
#
# Se `fix_imports` for Verdadeiro e o protocolo for menor que 3, piclkes tenta mapear os novos nomes do Python3 para os nomes do módulo antigo utilizados no Python2, de modo que o fluxo de dados pickles seja legível com Python2.
#
# Os objetos que foram descarregados num arquivo com `picles.dump` podem ser relidos num programa usando o método de `piclke.load(file)`. Esse método reconhece automaticamente o formato que tinha sido usado para escrever os dados.
#
# Exemplo simples:

# %%
import pickle
cidades = ['Pirenópolis', 'Corumbá', 'Luziânia', 'Cidade de Goiás', 'Cavalcante']
fh = open('dados.pkl', 'wb')
pickle.dump(cidades, fh)
fh.close()

# %% [markdown]
# O arquivo de "dados.pkl" pode ser lido novamente por Python, na mesma ou em outra sessão ou por um programa diferente:

# %%
f = open("dados.pkl", "rb")
cids = pickle.load(f)
print(cids)
# Out:
# ['Pirenópolis', 'Corumbá', 'Luziânia', 'Cidade de Goiás', 'Cavalcante']

# %% [markdown]
# Apenas os objetos, não os seus nomes, são guardados. É por isso que usamos a atribuição de 'cids' no exemplo anterior, ou seja, cids = pickle.load(f).
#
# O exemplo anterior teve em conserva apenas um objeto, por exemplo, uma lista das cidades goianas mais antigas. Mas como seria a consevação de vários objetos? A solução é fácil: arrumar os objetos em outro objeto, portanto, só teremos de serializar um objeto novamente. Vamos embalar duas listas 'linguagens_programação' e 'dialetos_python' em uma lista objeto_pickle no exemplo a seguir:

# %%
fh = open("dados2.pkl","bw")
linguagens_programação = ["Python", "Perl", "C++", "Java", "Lisp"]
dialetos_python = ["Jython", "IronPython", "CPython"]
objeto_pickle = (linguagens_programação, dialetos_python)
pickle.dump(objeto_pickle,fh)
fh.close()

# %% [markdown]
# A conserva de dados do exemplo anterior, isto é, os dados que temos escrito para o arquivo 'dados2.pkl', pode ser separada em duas listas, novamente, quando relermos os dados:

# %%
f = open('dados2.pkl','rb')
(lings, dialetos) = pickle.load(f) 
print(lings, dialetos)
# Out:
# ['Python', 'Perl', 'C++', 'Java', 'Lisp'] ['Jython', 'IronPython', 'CPython']

# %% [markdown]
# ## Fim.
# <p style="text-align:right;"><a href='../Índice.ipynb' target="_self">Volta ao Índice</a></p>

# %% [markdown]
# ## Anexo - Biblioteca Padrão do Python
# <a id="anexo"></a>Alguns dos módulos mais importantes dessa biblioteca:
#
# * Matemática: `math, cmath, decimal e random`.
#
# * regex: `re`- módulo de expressões regulares com funções muito poderosas para manipulação de texto.
#
# * Sistema Operacional: `os, io, sys, glob, logging, shutils e subprocess`.
#
# * Threads (linhas de processamento): `threading`.
#
# * Manipulação de datas e horários: `datetime`.
#
# * Persistência de dados: `pickle e cPickle`.
#
# * XML: `xml.dom, xml.sax e elementTree`.
#
# * Configuração: `ConfigParser e optparse`.
#
# * Tempo: `time e datetime`.
#
# * Outros: `traceback, types, json e timeit`.
#
# Listagem completa dos módulos da **Biblioteca Padrão** da Ling. Python pode ser vista [aqui](https://onlinelibrary.wiley.com/doi/pdf/10.1002/9781119207580.app2), ou se quiser, podemos gerar a lista de módulos disponíveis na versão Python usada como base a esse Jupyter Notebook:

# %%
import distutils.sysconfig as sysconfig
import os
bibs = sysconfig.get_python_lib(standard_lib=True)
# Se standard_lib for True, o diretório para a biblioteca padrão é retornado 
# em vez do diretório para a instalação de extensões de terceiros.
n = 0
for topo, dirs, arqs in os.walk(bibs):
    for arq in arqs:
        if arq != '__init__.py' and arq[-3:] == '.py':
            print(os.path.join(topo, arq)[len(bibPadrao)+1:-3].replace(os.sep, '.'))
            n += 1
print(f"\n* Total de módulos instalados: {n}")
# Out:
# abc
# aifc
# antigravity
# argparse
# ast
# asynchat
# asyncore
# base64
# bdb
# binhex
# bisect
# bz2
# calendar
# cgi
# cgitb
# chunk
# cmd
# code
# codecs
# codeop
# colorsys
# compileall
# configparser
# contextlib
# contextvars
# copy
# copyreg
# cProfile
# crypt
# csv
# dataclasses
# datetime
# decimal
# difflib
# dis
# doctest
# dummy_threading
# enum
# filecmp
# fileinput
# fnmatch
# formatter
# fractions
# ftplib
# functools
# genericpath
# getopt
# getpass
# gettext
# glob
# gzip
# hashlib
# heapq
# hmac
# imaplib
# imghdr
# imp
# inspect
# io
# ipaddress
# keyword
# linecache
# locale
# lzma
# mailbox
# mailcap
# mimetypes
# modulefinder
# netrc
# nntplib
# ntpath
# nturl2path
# numbers
# opcode
# operator
# optparse
# os
# pathlib
# pdb
# pickle
# pickletools
# pipes
# pkgutil
# platform
# plistlib
# poplib
# posixpath
# pprint
# profile
# pstats
# pty
# pyclbr
# pydoc
# py_compile
# queue
# quopri
# random
# re
# reprlib
# rlcompleter
# runpy
# sched
# secrets
# selectors
# shelve
# shlex
# shutil
# signal
# site
# smtpd
# smtplib
# sndhdr
# socket
# socketserver
# sre_compile
# sre_constants
# sre_parse
# ssl
# stat
# statistics
# string
# stringprep
# struct
# subprocess
# sunau
# symbol
# symtable
# sysconfig
# tabnanny
# tarfile
# telnetlib
# tempfile
# textwrap
# this
# threading
# timeit
# token
# tokenize
# trace
# traceback
# tracemalloc
# tty
# turtle
# types
# typing
# uu
# uuid
# warnings
# wave
# weakref
# webbrowser
# xdrlib
# zipapp
# zipfile
# zipimport
# _bootlocale
# _collections_abc
# _compat_pickle
# _compression
# _dummy_thread
# _markupbase
# _nsis
# _osx_support
# _pydecimal
# _pyio
# _py_abc
# _sitebuiltins
# _strptime
# _system_path
# _threading_local
# _weakrefset
# __future__
# __phello__.foo
# asyncio.base_events
# asyncio.base_futures
# asyncio.base_subprocess
# asyncio.base_tasks
# asyncio.constants
# asyncio.coroutines
# asyncio.events
# asyncio.exceptions
# asyncio.format_helpers
# asyncio.futures
# asyncio.locks
# asyncio.log
# asyncio.proactor_events
# asyncio.protocols
# asyncio.queues
# asyncio.runners
# asyncio.selector_events
# asyncio.sslproto
# asyncio.staggered
# asyncio.streams
# asyncio.subprocess
# asyncio.tasks
# asyncio.transports
# asyncio.trsock
# asyncio.unix_events
# asyncio.windows_events
# asyncio.windows_utils
# asyncio.__main__
# collections.abc
# concurrent.futures.process
# concurrent.futures.thread
# concurrent.futures._base
# ctypes.util
# ctypes.wintypes
# ctypes._aix
# ctypes._endian
# ctypes.macholib.dyld
# ctypes.macholib.dylib
# ctypes.macholib.framework
# ctypes.test.test_anon
# ctypes.test.test_arrays
# ctypes.test.test_array_in_pointer
# ctypes.test.test_as_parameter
# ctypes.test.test_bitfields
# ctypes.test.test_buffers
# ctypes.test.test_bytes
# ctypes.test.test_byteswap
# ctypes.test.test_callbacks
# ctypes.test.test_cast
# ctypes.test.test_cfuncs
# ctypes.test.test_checkretval
# ctypes.test.test_delattr
# ctypes.test.test_errno
# ctypes.test.test_find
# ctypes.test.test_frombuffer
# ctypes.test.test_funcptr
# ctypes.test.test_functions
# ctypes.test.test_incomplete
# ctypes.test.test_init
# ctypes.test.test_internals
# ctypes.test.test_keeprefs
# ctypes.test.test_libc
# ctypes.test.test_loading
# ctypes.test.test_macholib
# ctypes.test.test_memfunctions
# ctypes.test.test_numbers
# ctypes.test.test_objects
# ctypes.test.test_parameters
# ctypes.test.test_pep3118
# ctypes.test.test_pickling
# ctypes.test.test_pointers
# ctypes.test.test_prototypes
# ctypes.test.test_python_api
# ctypes.test.test_random_things
# ctypes.test.test_refcounts
# ctypes.test.test_repr
# ctypes.test.test_returnfuncptrs
# ctypes.test.test_simplesubclasses
# ctypes.test.test_sizes
# ctypes.test.test_slicing
# ctypes.test.test_stringptr
# ctypes.test.test_strings
# ctypes.test.test_structures
# ctypes.test.test_struct_fields
# ctypes.test.test_unaligned_structures
# ctypes.test.test_unicode
# ctypes.test.test_values
# ctypes.test.test_varsize_struct
# ctypes.test.test_win32
# ctypes.test.test_wintypes
# ctypes.test.__main__
# curses.ascii
# curses.has_key
# curses.panel
# curses.textpad
# dbm.dumb
# dbm.gnu
# dbm.ndbm
# distutils.archive_util
# distutils.bcppcompiler
# distutils.ccompiler
# distutils.cmd
# distutils.config
# distutils.core
# distutils.cygwinccompiler
# distutils.debug
# distutils.dep_util
# distutils.dir_util
# distutils.dist
# distutils.errors
# distutils.extension
# distutils.fancy_getopt
# distutils.filelist
# distutils.file_util
# distutils.log
# distutils.msvc9compiler
# distutils.msvccompiler
# distutils.spawn
# distutils.sysconfig
# distutils.text_file
# distutils.unixccompiler
# distutils.util
# distutils.version
# distutils.versionpredicate
# distutils._msvccompiler
# distutils.command.bdist
# distutils.command.bdist_conda
# distutils.command.bdist_dumb
# distutils.command.bdist_msi
# distutils.command.bdist_rpm
# distutils.command.bdist_wininst
# distutils.command.build
# distutils.command.build_clib
# distutils.command.build_ext
# distutils.command.build_py
# distutils.command.build_scripts
# distutils.command.check
# distutils.command.clean
# distutils.command.config
# distutils.command.install
# distutils.command.install_data
# distutils.command.install_egg_info
# distutils.command.install_headers
# distutils.command.install_lib
# distutils.command.install_scripts
# distutils.command.register
# distutils.command.sdist
# distutils.command.upload
# distutils.tests.support
# distutils.tests.test_archive_util
# distutils.tests.test_bdist
# distutils.tests.test_bdist_dumb
# distutils.tests.test_bdist_msi
# distutils.tests.test_bdist_rpm
# distutils.tests.test_bdist_wininst
# distutils.tests.test_build
# distutils.tests.test_build_clib
# distutils.tests.test_build_ext
# distutils.tests.test_build_py
# distutils.tests.test_build_scripts
# distutils.tests.test_check
# distutils.tests.test_clean
# distutils.tests.test_cmd
# distutils.tests.test_config
# distutils.tests.test_config_cmd
# distutils.tests.test_core
# distutils.tests.test_cygwinccompiler
# distutils.tests.test_dep_util
# distutils.tests.test_dir_util
# distutils.tests.test_dist
# distutils.tests.test_extension
# distutils.tests.test_filelist
# distutils.tests.test_file_util
# distutils.tests.test_install
# distutils.tests.test_install_data
# distutils.tests.test_install_headers
# distutils.tests.test_install_lib
# distutils.tests.test_install_scripts
# distutils.tests.test_log
# distutils.tests.test_msvc9compiler
# distutils.tests.test_msvccompiler
# distutils.tests.test_register
# distutils.tests.test_sdist
# distutils.tests.test_spawn
# distutils.tests.test_sysconfig
# distutils.tests.test_text_file
# distutils.tests.test_unixccompiler
# distutils.tests.test_upload
# distutils.tests.test_util
# distutils.tests.test_version
# distutils.tests.test_versionpredicate
# email.base64mime
# email.charset
# email.contentmanager
# email.encoders
# email.errors
# email.feedparser
# email.generator
# email.header
# email.headerregistry
# email.iterators
# email.message
# email.parser
# email.policy
# email.quoprimime
# email.utils
# email._encoded_words
# email._header_value_parser
# email._parseaddr
# email._policybase
# email.mime.application
# email.mime.audio
# email.mime.base
# email.mime.image
# email.mime.message
# email.mime.multipart
# email.mime.nonmultipart
# email.mime.text
# encodings.aliases
# encodings.ascii
# encodings.base64_codec
# encodings.big5
# encodings.big5hkscs
# encodings.bz2_codec
# encodings.charmap
# encodings.cp037
# encodings.cp1006
# encodings.cp1026
# encodings.cp1125
# encodings.cp1140
# encodings.cp1250
# encodings.cp1251
# encodings.cp1252
# encodings.cp1253
# encodings.cp1254
# encodings.cp1255
# encodings.cp1256
# encodings.cp1257
# encodings.cp1258
# encodings.cp273
# encodings.cp424
# encodings.cp437
# encodings.cp500
# encodings.cp720
# encodings.cp737
# encodings.cp775
# encodings.cp850
# encodings.cp852
# encodings.cp855
# encodings.cp856
# encodings.cp857
# encodings.cp858
# encodings.cp860
# encodings.cp861
# encodings.cp862
# encodings.cp863
# encodings.cp864
# encodings.cp865
# encodings.cp866
# encodings.cp869
# encodings.cp874
# encodings.cp875
# encodings.cp932
# encodings.cp949
# encodings.cp950
# encodings.euc_jisx0213
# encodings.euc_jis_2004
# encodings.euc_jp
# encodings.euc_kr
# encodings.gb18030
# encodings.gb2312
# encodings.gbk
# encodings.hex_codec
# encodings.hp_roman8
# encodings.hz
# encodings.idna
# encodings.iso2022_jp
# encodings.iso2022_jp_1
# encodings.iso2022_jp_2
# encodings.iso2022_jp_2004
# encodings.iso2022_jp_3
# encodings.iso2022_jp_ext
# encodings.iso2022_kr
# encodings.iso8859_1
# encodings.iso8859_10
# encodings.iso8859_11
# encodings.iso8859_13
# encodings.iso8859_14
# encodings.iso8859_15
# encodings.iso8859_16
# encodings.iso8859_2
# encodings.iso8859_3
# encodings.iso8859_4
# encodings.iso8859_5
# encodings.iso8859_6
# encodings.iso8859_7
# encodings.iso8859_8
# encodings.iso8859_9
# encodings.johab
# encodings.koi8_r
# encodings.koi8_t
# encodings.koi8_u
# encodings.kz1048
# encodings.latin_1
# encodings.mac_arabic
# encodings.mac_centeuro
# encodings.mac_croatian
# encodings.mac_cyrillic
# encodings.mac_farsi
# encodings.mac_greek
# encodings.mac_iceland
# encodings.mac_latin2
# encodings.mac_roman
# encodings.mac_romanian
# encodings.mac_turkish
# encodings.mbcs
# encodings.oem
# encodings.palmos
# encodings.ptcp154
# encodings.punycode
# encodings.quopri_codec
# encodings.raw_unicode_escape
# encodings.rot_13
# encodings.shift_jis
# encodings.shift_jisx0213
# encodings.shift_jis_2004
# encodings.tis_620
# encodings.undefined
# encodings.unicode_escape
# encodings.utf_16
# encodings.utf_16_be
# encodings.utf_16_le
# encodings.utf_32
# encodings.utf_32_be
# encodings.utf_32_le
# encodings.utf_7
# encodings.utf_8
# encodings.utf_8_sig
# encodings.uu_codec
# encodings.zlib_codec
# ensurepip._uninstall
# ensurepip.__main__
# html.entities
# html.parser
# http.client
# http.cookiejar
# http.cookies
# http.server
# idlelib.autocomplete
# idlelib.autocomplete_w
# idlelib.autoexpand
# idlelib.browser
# idlelib.calltip
# idlelib.calltip_w
# idlelib.codecontext
# idlelib.colorizer
# idlelib.config
# idlelib.configdialog
# idlelib.config_key
# idlelib.debugger
# idlelib.debugger_r
# idlelib.debugobj
# idlelib.debugobj_r
# idlelib.delegator
# idlelib.dynoption
# idlelib.editor
# idlelib.filelist
# idlelib.format
# idlelib.grep
# idlelib.help
# idlelib.help_about
# idlelib.history
# idlelib.hyperparser
# idlelib.idle
# idlelib.iomenu
# idlelib.macosx
# idlelib.mainmenu
# idlelib.multicall
# idlelib.outwin
# idlelib.parenmatch
# idlelib.pathbrowser
# idlelib.percolator
# idlelib.pyparse
# idlelib.pyshell
# idlelib.query
# idlelib.redirector
# idlelib.replace
# idlelib.rpc
# idlelib.run
# idlelib.runscript
# idlelib.scrolledlist
# idlelib.search
# idlelib.searchbase
# idlelib.searchengine
# idlelib.sidebar
# idlelib.squeezer
# idlelib.stackviewer
# idlelib.statusbar
# idlelib.textview
# idlelib.tooltip
# idlelib.tree
# idlelib.undo
# idlelib.window
# idlelib.zoomheight
# idlelib.zzdummy
# idlelib.__main__
# idlelib.idle_test.htest
# idlelib.idle_test.mock_idle
# idlelib.idle_test.mock_tk
# idlelib.idle_test.template
# idlelib.idle_test.test_autocomplete
# idlelib.idle_test.test_autocomplete_w
# idlelib.idle_test.test_autoexpand
# idlelib.idle_test.test_browser
# idlelib.idle_test.test_calltip
# idlelib.idle_test.test_calltip_w
# idlelib.idle_test.test_codecontext
# idlelib.idle_test.test_colorizer
# idlelib.idle_test.test_config
# idlelib.idle_test.test_configdialog
# idlelib.idle_test.test_config_key
# idlelib.idle_test.test_debugger
# idlelib.idle_test.test_debugger_r
# idlelib.idle_test.test_debugobj
# idlelib.idle_test.test_debugobj_r
# idlelib.idle_test.test_delegator
# idlelib.idle_test.test_editmenu
# idlelib.idle_test.test_editor
# idlelib.idle_test.test_filelist
# idlelib.idle_test.test_format
# idlelib.idle_test.test_grep
# idlelib.idle_test.test_help
# idlelib.idle_test.test_help_about
# idlelib.idle_test.test_history
# idlelib.idle_test.test_hyperparser
# idlelib.idle_test.test_iomenu
# idlelib.idle_test.test_macosx
# idlelib.idle_test.test_mainmenu
# idlelib.idle_test.test_multicall
# idlelib.idle_test.test_outwin
# idlelib.idle_test.test_parenmatch
# idlelib.idle_test.test_pathbrowser
# idlelib.idle_test.test_percolator
# idlelib.idle_test.test_pyparse
# idlelib.idle_test.test_pyshell
# idlelib.idle_test.test_query
# idlelib.idle_test.test_redirector
# idlelib.idle_test.test_replace
# idlelib.idle_test.test_rpc
# idlelib.idle_test.test_run
# idlelib.idle_test.test_runscript
# idlelib.idle_test.test_scrolledlist
# idlelib.idle_test.test_search
# idlelib.idle_test.test_searchbase
# idlelib.idle_test.test_searchengine
# idlelib.idle_test.test_sidebar
# idlelib.idle_test.test_squeezer
# idlelib.idle_test.test_stackviewer
# idlelib.idle_test.test_statusbar
# idlelib.idle_test.test_text
# idlelib.idle_test.test_textview
# idlelib.idle_test.test_tooltip
# idlelib.idle_test.test_tree
# idlelib.idle_test.test_undo
# idlelib.idle_test.test_warning
# idlelib.idle_test.test_window
# idlelib.idle_test.test_zoomheight
# importlib.abc
# importlib.machinery
# importlib.metadata
# importlib.resources
# importlib.util
# importlib._bootstrap
# importlib._bootstrap_external
# json.decoder
# json.encoder
# json.scanner
# json.tool
# lib2to3.btm_matcher
# lib2to3.btm_utils
# lib2to3.fixer_base
# lib2to3.fixer_util
# lib2to3.main
# lib2to3.patcomp
# lib2to3.pygram
# lib2to3.pytree
# lib2to3.refactor
# lib2to3.__main__
# lib2to3.fixes.fix_apply
# lib2to3.fixes.fix_asserts
# lib2to3.fixes.fix_basestring
# lib2to3.fixes.fix_buffer
# lib2to3.fixes.fix_dict
# lib2to3.fixes.fix_except
# lib2to3.fixes.fix_exec
# lib2to3.fixes.fix_execfile
# lib2to3.fixes.fix_exitfunc
# lib2to3.fixes.fix_filter
# lib2to3.fixes.fix_funcattrs
# lib2to3.fixes.fix_future
# lib2to3.fixes.fix_getcwdu
# lib2to3.fixes.fix_has_key
# lib2to3.fixes.fix_idioms
# lib2to3.fixes.fix_import
# lib2to3.fixes.fix_imports
# lib2to3.fixes.fix_imports2
# lib2to3.fixes.fix_input
# lib2to3.fixes.fix_intern
# lib2to3.fixes.fix_isinstance
# lib2to3.fixes.fix_itertools
# lib2to3.fixes.fix_itertools_imports
# lib2to3.fixes.fix_long
# lib2to3.fixes.fix_map
# lib2to3.fixes.fix_metaclass
# lib2to3.fixes.fix_methodattrs
# lib2to3.fixes.fix_ne
# lib2to3.fixes.fix_next
# lib2to3.fixes.fix_nonzero
# lib2to3.fixes.fix_numliterals
# lib2to3.fixes.fix_operator
# lib2to3.fixes.fix_paren
# lib2to3.fixes.fix_print
# lib2to3.fixes.fix_raise
# lib2to3.fixes.fix_raw_input
# lib2to3.fixes.fix_reduce
# lib2to3.fixes.fix_reload
# lib2to3.fixes.fix_renames
# lib2to3.fixes.fix_repr
# lib2to3.fixes.fix_set_literal
# lib2to3.fixes.fix_standarderror
# lib2to3.fixes.fix_sys_exc
# lib2to3.fixes.fix_throw
# lib2to3.fixes.fix_tuple_params
# lib2to3.fixes.fix_types
# lib2to3.fixes.fix_unicode
# lib2to3.fixes.fix_urllib
# lib2to3.fixes.fix_ws_comma
# lib2to3.fixes.fix_xrange
# lib2to3.fixes.fix_xreadlines
# lib2to3.fixes.fix_zip
# lib2to3.pgen2.conv
# lib2to3.pgen2.driver
# lib2to3.pgen2.grammar
# lib2to3.pgen2.literals
# lib2to3.pgen2.parse
# lib2to3.pgen2.pgen
# lib2to3.pgen2.token
# lib2to3.pgen2.tokenize
# logging.config
# logging.handlers
# msilib.schema
# msilib.sequence
# msilib.text
# multiprocessing.connection
# multiprocessing.context
# multiprocessing.forkserver
# multiprocessing.heap
# multiprocessing.managers
# multiprocessing.pool
# multiprocessing.popen_fork
# multiprocessing.popen_forkserver
# multiprocessing.popen_spawn_posix
# multiprocessing.popen_spawn_win32
# multiprocessing.process
# multiprocessing.queues
# multiprocessing.reduction
# multiprocessing.resource_sharer
# multiprocessing.resource_tracker
# multiprocessing.sharedctypes
# multiprocessing.shared_memory
# multiprocessing.spawn
# multiprocessing.synchronize
# multiprocessing.util
# multiprocessing.dummy.connection
# pydoc_data.topics
# site-packages.autopep8
# site-packages.contextlib2
# site-packages.cycler
# site-packages.cython
# site-packages.decorator
# site-packages.django_six
# site-packages.easy_install
# site-packages.entrypoints
# site-packages.filelock
# site-packages.heapdict
# site-packages.imagesize
# site-packages.ipykernel_launcher
# site-packages.isympy
# site-packages.jdcal
# site-packages.jupyter
# site-packages.mccabe
# site-packages.mistune
# site-packages.pandocfilters
# site-packages.pep8
# site-packages.pickleshare
# site-packages.pycodestyle
# site-packages.pylab
# site-packages.pyparsing
# site-packages.pythoncom
# site-packages.readline
# site-packages.run
# site-packages.simplegeneric
# site-packages.singledispatch
# site-packages.singledispatch_helpers
# site-packages.sipconfig
# site-packages.sipdistutils
# site-packages.six
# site-packages.socks
# site-packages.sockshandler
# site-packages.test_pycosat
# site-packages.threadpoolctl
# site-packages.typing_extensions
# site-packages.wincertstore
# site-packages.win_inet_pton
# site-packages.xmltodict
# site-packages.zipp
# site-packages._pyrsistent_version
# site-packages.admin_reports.apps
# site-packages.admin_reports.decorators
# site-packages.admin_reports.forms
# site-packages.admin_reports.reports
# site-packages.admin_reports.sites
# site-packages.admin_reports.views
# site-packages.adodbapi.adodbapi
# site-packages.adodbapi.ado_consts
# site-packages.adodbapi.is64bit
# site-packages.adodbapi.schema_table
# site-packages.adodbapi.examples.db_print
# site-packages.adodbapi.examples.db_table_names
# site-packages.adodbapi.examples.xls_read
# site-packages.adodbapi.examples.xls_write
# site-packages.adodbapi.test.adodbapitest
# site-packages.adodbapi.test.adodbapitestconfig
# site-packages.adodbapi.test.dbapi20
# site-packages.adodbapi.test.is64bit
# site-packages.adodbapi.test.setuptestframework
# site-packages.adodbapi.test.test_adodbapi_dbapi20
# site-packages.adodbapi.test.tryconnection2
# site-packages.adodbapi.test.tryconnection3
# site-packages.alabaster.support
# site-packages.alabaster._version
# site-packages.anaconda_navigator.exceptions
# site-packages.anaconda_navigator.api.anaconda_api
# site-packages.anaconda_navigator.api.client_api
# site-packages.anaconda_navigator.api.conda_api
# site-packages.anaconda_navigator.api.download_api
# site-packages.anaconda_navigator.api.process
# site-packages.anaconda_navigator.api.project_api
# site-packages.anaconda_navigator.api.external_apps.base
# site-packages.anaconda_navigator.api.external_apps.pycharm
# site-packages.anaconda_navigator.api.external_apps.vscode
# site-packages.anaconda_navigator.api.tests.test_anaconda_api
# site-packages.anaconda_navigator.api.tests.test_client_api
# site-packages.anaconda_navigator.api.tests.test_conda_api
# site-packages.anaconda_navigator.app.cli
# site-packages.anaconda_navigator.app.main
# site-packages.anaconda_navigator.app.start
# site-packages.anaconda_navigator.config.base
# site-packages.anaconda_navigator.config.main
# site-packages.anaconda_navigator.config.user
# site-packages.anaconda_navigator.external.filelock
# site-packages.anaconda_navigator.external.knownfolders
# site-packages.anaconda_navigator.external.binaryornot.check
# site-packages.anaconda_navigator.external.binaryornot.utils
# site-packages.anaconda_navigator.external.UniversalAnalytics.HTTPLog
# site-packages.anaconda_navigator.external.UniversalAnalytics.Tracker
# site-packages.anaconda_navigator.static.scripts.vscodeinstall
# site-packages.anaconda_navigator.utils.analytics
# site-packages.anaconda_navigator.utils.conda
# site-packages.anaconda_navigator.utils.constants
# site-packages.anaconda_navigator.utils.encoding
# site-packages.anaconda_navigator.utils.findpip
# site-packages.anaconda_navigator.utils.fixtures
# site-packages.anaconda_navigator.utils.launch
# site-packages.anaconda_navigator.utils.logs
# site-packages.anaconda_navigator.utils.misc
# site-packages.anaconda_navigator.utils.pretty_json
# site-packages.anaconda_navigator.utils.programs
# site-packages.anaconda_navigator.utils.py3compat
# site-packages.anaconda_navigator.utils.qthelpers
# site-packages.anaconda_navigator.utils.styles
# site-packages.anaconda_navigator.utils.toolpath
# site-packages.anaconda_navigator.utils.win_elevate
# site-packages.anaconda_navigator.widgets.explorer
# site-packages.anaconda_navigator.widgets.helperwidgets
# site-packages.anaconda_navigator.widgets.main_window
# site-packages.anaconda_navigator.widgets.projects
# site-packages.anaconda_navigator.widgets.spinner
# site-packages.anaconda_navigator.widgets.dialogs.about
# site-packages.anaconda_navigator.widgets.dialogs.channels
# site-packages.anaconda_navigator.widgets.dialogs.environment
# site-packages.anaconda_navigator.widgets.dialogs.license
# site-packages.anaconda_navigator.widgets.dialogs.logger
# site-packages.anaconda_navigator.widgets.dialogs.login
# site-packages.anaconda_navigator.widgets.dialogs.offline
# site-packages.anaconda_navigator.widgets.dialogs.packages
# site-packages.anaconda_navigator.widgets.dialogs.password
# site-packages.anaconda_navigator.widgets.dialogs.preferences
# site-packages.anaconda_navigator.widgets.dialogs.projects
# site-packages.anaconda_navigator.widgets.dialogs.quit
# site-packages.anaconda_navigator.widgets.dialogs.splash
# site-packages.anaconda_navigator.widgets.dialogs.update
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_about_dialog
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_channels
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_environment_dialogs
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_license_manager
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_logger
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_login_dialog
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_messagebox
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_packages
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_preferences
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_projects
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_quit_dialog
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_splash
# site-packages.anaconda_navigator.widgets.dialogs.tests.test_update_dialog
# site-packages.anaconda_navigator.widgets.lists.apps
# site-packages.anaconda_navigator.widgets.lists.content
# site-packages.anaconda_navigator.widgets.lists.environments
# site-packages.anaconda_navigator.widgets.lists.projects
# site-packages.anaconda_navigator.widgets.manager.filter
# site-packages.anaconda_navigator.widgets.manager.model
# site-packages.anaconda_navigator.widgets.manager.packages
# site-packages.anaconda_navigator.widgets.manager.table
# site-packages.anaconda_navigator.widgets.manager.tests.test_manager
# site-packages.anaconda_navigator.widgets.manager.tests.test_table
# site-packages.anaconda_navigator.widgets.tabs.community
# site-packages.anaconda_navigator.widgets.tabs.environments
# site-packages.anaconda_navigator.widgets.tabs.home
# site-packages.anaconda_navigator.widgets.tabs.projects
# site-packages.anaconda_navigator.widgets.tabs.tabwidget
# site-packages.anaconda_navigator.widgets.tabs.tests.test_community_tab
# site-packages.anaconda_navigator.widgets.tabs.tests.test_environments_tab
# site-packages.anaconda_navigator.widgets.tests.test_endpoint_content
# site-packages.anaconda_navigator.widgets.tests.test_main_window
# site-packages.anaconda_project.api
# site-packages.anaconda_project.archiver
# site-packages.anaconda_project.cli
# site-packages.anaconda_project.client
# site-packages.anaconda_project.conda_manager
# site-packages.anaconda_project.env_spec
# site-packages.anaconda_project.frontend
# site-packages.anaconda_project.local_state_file
# site-packages.anaconda_project.plugins
# site-packages.anaconda_project.prepare
# site-packages.anaconda_project.project
# site-packages.anaconda_project.project_commands
# site-packages.anaconda_project.project_file
# site-packages.anaconda_project.project_lock_file
# site-packages.anaconda_project.project_ops
# site-packages.anaconda_project.provide
# site-packages.anaconda_project.status
# site-packages.anaconda_project.verbose
# site-packages.anaconda_project.version
# site-packages.anaconda_project.yaml_file
# site-packages.anaconda_project.internal.conda_api
# site-packages.anaconda_project.internal.default_conda_manager
# site-packages.anaconda_project.internal.directory_contains
# site-packages.anaconda_project.internal.http_client
# site-packages.anaconda_project.internal.keyring
# site-packages.anaconda_project.internal.logged_subprocess
# site-packages.anaconda_project.internal.makedirs
# site-packages.anaconda_project.internal.metaclass
# site-packages.anaconda_project.internal.notebook_analyzer
# site-packages.anaconda_project.internal.pip_api
# site-packages.anaconda_project.internal.plugins
# site-packages.anaconda_project.internal.py2_compat
# site-packages.anaconda_project.internal.rename
# site-packages.anaconda_project.internal.simple_status
# site-packages.anaconda_project.internal.slugify
# site-packages.anaconda_project.internal.streaming_popen
# site-packages.anaconda_project.internal.toposort
# site-packages.anaconda_project.internal.windows_cmdline
# site-packages.anaconda_project.internal.ziputils
# site-packages.anaconda_project.internal.cli.activate
# site-packages.anaconda_project.internal.cli.archive
# site-packages.anaconda_project.internal.cli.bug_handler
# site-packages.anaconda_project.internal.cli.clean
# site-packages.anaconda_project.internal.cli.command_commands
# site-packages.anaconda_project.internal.cli.console_utils
# site-packages.anaconda_project.internal.cli.download
# site-packages.anaconda_project.internal.cli.download_commands
# site-packages.anaconda_project.internal.cli.environment_commands
# site-packages.anaconda_project.internal.cli.init
# site-packages.anaconda_project.internal.cli.main
# site-packages.anaconda_project.internal.cli.prepare
# site-packages.anaconda_project.internal.cli.prepare_with_mode
# site-packages.anaconda_project.internal.cli.project_load
# site-packages.anaconda_project.internal.cli.run
# site-packages.anaconda_project.internal.cli.service_commands
# site-packages.anaconda_project.internal.cli.unarchive
# site-packages.anaconda_project.internal.cli.upload
# site-packages.anaconda_project.internal.cli.variable_commands
# site-packages.anaconda_project.internal.cli.test.test_activate
# site-packages.anaconda_project.internal.cli.test.test_bug_handler
# site-packages.anaconda_project.internal.cli.test.test_bundle
# site-packages.anaconda_project.internal.cli.test.test_clean
# site-packages.anaconda_project.internal.cli.test.test_command_commands
# site-packages.anaconda_project.internal.cli.test.test_console_utils
# site-packages.anaconda_project.internal.cli.test.test_download
# site-packages.anaconda_project.internal.cli.test.test_download_commands
# site-packages.anaconda_project.internal.cli.test.test_environment_commands
# site-packages.anaconda_project.internal.cli.test.test_init
# site-packages.anaconda_project.internal.cli.test.test_main
# site-packages.anaconda_project.internal.cli.test.test_prepare
# site-packages.anaconda_project.internal.cli.test.test_project_load
# site-packages.anaconda_project.internal.cli.test.test_run
# site-packages.anaconda_project.internal.cli.test.test_service_commands
# site-packages.anaconda_project.internal.cli.test.test_unarchive
# site-packages.anaconda_project.internal.cli.test.test_upload
# site-packages.anaconda_project.internal.cli.test.test_variable_commands
# site-packages.anaconda_project.internal.test.fake_frontend
# site-packages.anaconda_project.internal.test.fields
# site-packages.anaconda_project.internal.test.http_server
# site-packages.anaconda_project.internal.test.http_utils
# site-packages.anaconda_project.internal.test.multipart
# site-packages.anaconda_project.internal.test.test_conda_api
# site-packages.anaconda_project.internal.test.test_default_conda_manager
# site-packages.anaconda_project.internal.test.test_directory_contains
# site-packages.anaconda_project.internal.test.test_http_client
# site-packages.anaconda_project.internal.test.test_keyring
# site-packages.anaconda_project.internal.test.test_logged_subprocess
# site-packages.anaconda_project.internal.test.test_makedirs
# site-packages.anaconda_project.internal.test.test_notebook_analyzer
# site-packages.anaconda_project.internal.test.test_pip_api
# site-packages.anaconda_project.internal.test.test_rename
# site-packages.anaconda_project.internal.test.test_simple_status
# site-packages.anaconda_project.internal.test.test_slugify
# site-packages.anaconda_project.internal.test.test_streaming_popen
# site-packages.anaconda_project.internal.test.test_toposort
# site-packages.anaconda_project.internal.test.test_windows_cmdline
# site-packages.anaconda_project.internal.test.test_ziputils
# site-packages.anaconda_project.internal.test.tmpfile_utils
# site-packages.anaconda_project.requirements_registry.network_util
# site-packages.anaconda_project.requirements_registry.provider
# site-packages.anaconda_project.requirements_registry.registry
# site-packages.anaconda_project.requirements_registry.requirement
# site-packages.anaconda_project.requirements_registry.providers.conda_env
# site-packages.anaconda_project.requirements_registry.providers.download
# site-packages.anaconda_project.requirements_registry.providers.redis
# site-packages.anaconda_project.requirements_registry.providers.test.test_conda_bootstrap_env
# site-packages.anaconda_project.requirements_registry.providers.test.test_conda_env
# site-packages.anaconda_project.requirements_registry.providers.test.test_download_provider
# site-packages.anaconda_project.requirements_registry.providers.test.test_redis_provider
# site-packages.anaconda_project.requirements_registry.requirements.conda_env
# site-packages.anaconda_project.requirements_registry.requirements.download
# site-packages.anaconda_project.requirements_registry.requirements.redis
# site-packages.anaconda_project.requirements_registry.requirements.service
# site-packages.anaconda_project.requirements_registry.requirements.test.test_conda_env
# site-packages.anaconda_project.requirements_registry.requirements.test.test_download_requirement
# site-packages.anaconda_project.requirements_registry.requirements.test.test_redis_requirement
# site-packages.anaconda_project.requirements_registry.requirements.test.test_service_requirement
# site-packages.anaconda_project.requirements_registry.test.test_network_util
# site-packages.anaconda_project.requirements_registry.test.test_provider
# site-packages.anaconda_project.requirements_registry.test.test_requirement
# site-packages.anaconda_project.test.environ_utils
# site-packages.anaconda_project.test.fake_server
# site-packages.anaconda_project.test.project_utils
# site-packages.anaconda_project.test.test_api
# site-packages.anaconda_project.test.test_bundler
# site-packages.anaconda_project.test.test_cli
# site-packages.anaconda_project.test.test_client
# site-packages.anaconda_project.test.test_conda_manager
# site-packages.anaconda_project.test.test_env_spec
# site-packages.anaconda_project.test.test_frontend
# site-packages.anaconda_project.test.test_local_state_file
# site-packages.anaconda_project.test.test_plugins
# site-packages.anaconda_project.test.test_prepare
# site-packages.anaconda_project.test.test_project
# site-packages.anaconda_project.test.test_project_commands
# site-packages.anaconda_project.test.test_project_file
# site-packages.anaconda_project.test.test_project_lock_file
# site-packages.anaconda_project.test.test_project_ops
# site-packages.anaconda_project.test.test_version
# site-packages.anaconda_project.test.test_yaml_file
# site-packages.argh.assembling
# site-packages.argh.compat
# site-packages.argh.completion
# site-packages.argh.constants
# site-packages.argh.decorators
# site-packages.argh.dispatching
# site-packages.argh.exceptions
# site-packages.argh.helpers
# site-packages.argh.interaction
# site-packages.argh.io
# site-packages.argh.utils
# site-packages.asgiref.compatibility
# site-packages.asgiref.current_thread_executor
# site-packages.asgiref.local
# site-packages.asgiref.server
# site-packages.asgiref.sync
# site-packages.asgiref.testing
# site-packages.asgiref.timeout
# site-packages.asgiref.typing
# site-packages.asgiref.wsgi
# site-packages.asgiref._pep562
# site-packages.asn1crypto.algos
# site-packages.asn1crypto.cms
# site-packages.asn1crypto.core
# site-packages.asn1crypto.crl
# site-packages.asn1crypto.csr
# site-packages.asn1crypto.keys
# site-packages.asn1crypto.ocsp
# site-packages.asn1crypto.parser
# site-packages.asn1crypto.pdf
# site-packages.asn1crypto.pem
# site-packages.asn1crypto.pkcs12
# site-packages.asn1crypto.tsp
# site-packages.asn1crypto.util
# site-packages.asn1crypto.version
# site-packages.asn1crypto.x509
# site-packages.asn1crypto._errors
# site-packages.asn1crypto._inet
# site-packages.asn1crypto._int
# site-packages.asn1crypto._iri
# site-packages.asn1crypto._ordereddict
# site-packages.asn1crypto._teletex_codec
# site-packages.asn1crypto._types
# site-packages.astroid.arguments
# site-packages.astroid.as_string
# site-packages.astroid.bases
# site-packages.astroid.builder
# site-packages.astroid.context
# site-packages.astroid.decorators
# site-packages.astroid.exceptions
# site-packages.astroid.helpers
# site-packages.astroid.inference
# site-packages.astroid.manager
# site-packages.astroid.mixins
# site-packages.astroid.modutils
# site-packages.astroid.nodes
# site-packages.astroid.node_classes
# site-packages.astroid.objects
# site-packages.astroid.protocols
# site-packages.astroid.raw_building
# site-packages.astroid.rebuilder
# site-packages.astroid.scoped_nodes
# site-packages.astroid.test_utils
# site-packages.astroid.transforms
# site-packages.astroid.util
# site-packages.astroid._ast
# site-packages.astroid.__pkginfo__
# site-packages.astroid.brain.brain_argparse
# site-packages.astroid.brain.brain_attrs
# site-packages.astroid.brain.brain_boto3
# site-packages.astroid.brain.brain_builtin_inference
# site-packages.astroid.brain.brain_collections
# site-packages.astroid.brain.brain_crypt
# site-packages.astroid.brain.brain_curses
# site-packages.astroid.brain.brain_dataclasses
# site-packages.astroid.brain.brain_dateutil
# site-packages.astroid.brain.brain_fstrings
# site-packages.astroid.brain.brain_functools
# site-packages.astroid.brain.brain_gi
# site-packages.astroid.brain.brain_hashlib
# site-packages.astroid.brain.brain_http
# site-packages.astroid.brain.brain_io
# site-packages.astroid.brain.brain_mechanize
# site-packages.astroid.brain.brain_multiprocessing
# site-packages.astroid.brain.brain_namedtuple_enum
# site-packages.astroid.brain.brain_nose
# site-packages.astroid.brain.brain_numpy_core_fromnumeric
# site-packages.astroid.brain.brain_numpy_core_function_base
# site-packages.astroid.brain.brain_numpy_core_multiarray
# site-packages.astroid.brain.brain_numpy_core_numeric
# site-packages.astroid.brain.brain_numpy_core_numerictypes
# site-packages.astroid.brain.brain_numpy_core_umath
# site-packages.astroid.brain.brain_numpy_ndarray
# site-packages.astroid.brain.brain_numpy_random_mtrand
# site-packages.astroid.brain.brain_numpy_utils
# site-packages.astroid.brain.brain_pkg_resources
# site-packages.astroid.brain.brain_pytest
# site-packages.astroid.brain.brain_qt
# site-packages.astroid.brain.brain_random
# site-packages.astroid.brain.brain_re
# site-packages.astroid.brain.brain_responses
# site-packages.astroid.brain.brain_scipy_signal
# site-packages.astroid.brain.brain_six
# site-packages.astroid.brain.brain_ssl
# site-packages.astroid.brain.brain_subprocess
# site-packages.astroid.brain.brain_threading
# site-packages.astroid.brain.brain_typing
# site-packages.astroid.brain.brain_uuid
# site-packages.astroid.interpreter.dunder_lookup
# site-packages.astroid.interpreter.objectmodel
# site-packages.astroid.interpreter._import.spec
# site-packages.astroid.interpreter._import.util
# site-packages.astropy.conftest
# site-packages.astropy.cython_version
# site-packages.astropy.logger
# site-packages.astropy.setup_package
# site-packages.astropy.version
# site-packages.astropy.config.affiliated
# site-packages.astropy.config.configuration
# site-packages.astropy.config.paths
# site-packages.astropy.config.tests.test_configs
# site-packages.astropy.constants.astropyconst13
# site-packages.astropy.constants.astropyconst20
# site-packages.astropy.constants.astropyconst40
# site-packages.astropy.constants.cgs
# site-packages.astropy.constants.codata2010
# site-packages.astropy.constants.codata2014
# site-packages.astropy.constants.codata2018
# site-packages.astropy.constants.config
# site-packages.astropy.constants.constant
# site-packages.astropy.constants.iau2012
# site-packages.astropy.constants.iau2015
# site-packages.astropy.constants.si
# site-packages.astropy.constants.utils
# site-packages.astropy.constants.tests.test_constant
# site-packages.astropy.constants.tests.test_pickle
# site-packages.astropy.constants.tests.test_prior_version
# site-packages.astropy.constants.tests.test_sciencestate
# site-packages.astropy.convolution.convolve
# site-packages.astropy.convolution.core
# site-packages.astropy.convolution.kernels
# site-packages.astropy.convolution.setup_package
# site-packages.astropy.convolution.utils
# site-packages.astropy.convolution.tests.test_convolve
# site-packages.astropy.convolution.tests.test_convolve_fft
# site-packages.astropy.convolution.tests.test_convolve_kernels
# site-packages.astropy.convolution.tests.test_convolve_models
# site-packages.astropy.convolution.tests.test_convolve_nddata
# site-packages.astropy.convolution.tests.test_convolve_speeds
# site-packages.astropy.convolution.tests.test_discretize
# site-packages.astropy.convolution.tests.test_kernel_class
# site-packages.astropy.convolution.tests.test_pickle
# site-packages.astropy.coordinates.angles
# site-packages.astropy.coordinates.angle_lextab
# site-packages.astropy.coordinates.angle_parsetab
# site-packages.astropy.coordinates.angle_utilities
# site-packages.astropy.coordinates.attributes
# site-packages.astropy.coordinates.baseframe
# site-packages.astropy.coordinates.calculation
# site-packages.astropy.coordinates.distances
# site-packages.astropy.coordinates.earth
# site-packages.astropy.coordinates.earth_orientation
# site-packages.astropy.coordinates.errors
# site-packages.astropy.coordinates.funcs
# site-packages.astropy.coordinates.jparser
# site-packages.astropy.coordinates.matching
# site-packages.astropy.coordinates.matrix_utilities
# site-packages.astropy.coordinates.name_resolve
# site-packages.astropy.coordinates.orbital_elements
# site-packages.astropy.coordinates.representation
# site-packages.astropy.coordinates.sites
# site-packages.astropy.coordinates.sky_coordinate
# site-packages.astropy.coordinates.sky_coordinate_parsers
# site-packages.astropy.coordinates.solar_system
# site-packages.astropy.coordinates.transformations
# site-packages.astropy.coordinates.builtin_frames.altaz
# site-packages.astropy.coordinates.builtin_frames.baseradec
# site-packages.astropy.coordinates.builtin_frames.cirs
# site-packages.astropy.coordinates.builtin_frames.cirs_observed_transforms
# site-packages.astropy.coordinates.builtin_frames.ecliptic
# site-packages.astropy.coordinates.builtin_frames.ecliptic_transforms
# site-packages.astropy.coordinates.builtin_frames.fk4
# site-packages.astropy.coordinates.builtin_frames.fk4_fk5_transforms
# site-packages.astropy.coordinates.builtin_frames.fk5
# site-packages.astropy.coordinates.builtin_frames.galactic
# site-packages.astropy.coordinates.builtin_frames.galactic_transforms
# site-packages.astropy.coordinates.builtin_frames.galactocentric
# site-packages.astropy.coordinates.builtin_frames.gcrs
# site-packages.astropy.coordinates.builtin_frames.hcrs
# site-packages.astropy.coordinates.builtin_frames.icrs
# site-packages.astropy.coordinates.builtin_frames.icrs_cirs_transforms
# site-packages.astropy.coordinates.builtin_frames.icrs_fk5_transforms
# site-packages.astropy.coordinates.builtin_frames.intermediate_rotation_transforms
# site-packages.astropy.coordinates.builtin_frames.itrs
# site-packages.astropy.coordinates.builtin_frames.lsr
# site-packages.astropy.coordinates.builtin_frames.skyoffset
# site-packages.astropy.coordinates.builtin_frames.supergalactic
# site-packages.astropy.coordinates.builtin_frames.supergalactic_transforms
# site-packages.astropy.coordinates.builtin_frames.utils
# site-packages.astropy.coordinates.tests.conftest
# site-packages.astropy.coordinates.tests.test_angles
# site-packages.astropy.coordinates.tests.test_angular_separation
# site-packages.astropy.coordinates.tests.test_api_ape5
# site-packages.astropy.coordinates.tests.test_arrays
# site-packages.astropy.coordinates.tests.test_atc_replacements
# site-packages.astropy.coordinates.tests.test_celestial_transformations
# site-packages.astropy.coordinates.tests.test_distance
# site-packages.astropy.coordinates.tests.test_earth
# site-packages.astropy.coordinates.tests.test_finite_difference_velocities
# site-packages.astropy.coordinates.tests.test_formatting
# site-packages.astropy.coordinates.tests.test_frames
# site-packages.astropy.coordinates.tests.test_frames_with_velocity
# site-packages.astropy.coordinates.tests.test_funcs
# site-packages.astropy.coordinates.tests.test_iau_fullstack
# site-packages.astropy.coordinates.tests.test_intermediate_transformations
# site-packages.astropy.coordinates.tests.test_matching
# site-packages.astropy.coordinates.tests.test_matrix_utilities
# site-packages.astropy.coordinates.tests.test_name_resolve
# site-packages.astropy.coordinates.tests.test_pickle
# site-packages.astropy.coordinates.tests.test_regression
# site-packages.astropy.coordinates.tests.test_representation
# site-packages.astropy.coordinates.tests.test_representation_arithmetic
# site-packages.astropy.coordinates.tests.test_representation_methods
# site-packages.astropy.coordinates.tests.test_shape_manipulation
# site-packages.astropy.coordinates.tests.test_sites
# site-packages.astropy.coordinates.tests.test_skyoffset_transformations
# site-packages.astropy.coordinates.tests.test_sky_coord
# site-packages.astropy.coordinates.tests.test_sky_coord_velocities
# site-packages.astropy.coordinates.tests.test_solar_system
# site-packages.astropy.coordinates.tests.test_transformations
# site-packages.astropy.coordinates.tests.test_unit_representation
# site-packages.astropy.coordinates.tests.test_velocity_corrs
# site-packages.astropy.coordinates.tests.utils
# site-packages.astropy.coordinates.tests.accuracy.generate_ref_ast
# site-packages.astropy.coordinates.tests.accuracy.test_altaz_icrs
# site-packages.astropy.coordinates.tests.accuracy.test_ecliptic
# site-packages.astropy.coordinates.tests.accuracy.test_fk4_no_e_fk4
# site-packages.astropy.coordinates.tests.accuracy.test_fk4_no_e_fk5
# site-packages.astropy.coordinates.tests.accuracy.test_galactic_fk4
# site-packages.astropy.coordinates.tests.accuracy.test_icrs_fk5
# site-packages.astropy.cosmology.core
# site-packages.astropy.cosmology.funcs
# site-packages.astropy.cosmology.parameters
# site-packages.astropy.cosmology.tests.test_cosmology
# site-packages.astropy.cosmology.tests.test_pickle
# site-packages.astropy.extern._strptime
# site-packages.astropy.extern.configobj.configobj
# site-packages.astropy.extern.configobj.validate
# site-packages.astropy.extern.ply.cpp
# site-packages.astropy.extern.ply.ctokens
# site-packages.astropy.extern.ply.lex
# site-packages.astropy.extern.ply.yacc
# site-packages.astropy.extern.ply.ygen
# site-packages.astropy.io.registry
# site-packages.astropy.io.ascii.basic
# site-packages.astropy.io.ascii.cds
# site-packages.astropy.io.ascii.connect
# site-packages.astropy.io.ascii.core
# site-packages.astropy.io.ascii.daophot
# site-packages.astropy.io.ascii.docs
# site-packages.astropy.io.ascii.ecsv
# site-packages.astropy.io.ascii.fastbasic
# site-packages.astropy.io.ascii.fixedwidth
# site-packages.astropy.io.ascii.html
# site-packages.astropy.io.ascii.ipac
# site-packages.astropy.io.ascii.latex
# site-packages.astropy.io.ascii.misc
# site-packages.astropy.io.ascii.rst
# site-packages.astropy.io.ascii.setup_package
# site-packages.astropy.io.ascii.sextractor
# site-packages.astropy.io.ascii.ui
# site-packages.astropy.io.ascii.tests.common
# site-packages.astropy.io.ascii.tests.test_cds_header_from_readme
# site-packages.astropy.io.ascii.tests.test_compressed
# site-packages.astropy.io.ascii.tests.test_connect
# site-packages.astropy.io.ascii.tests.test_c_reader
# site-packages.astropy.io.ascii.tests.test_ecsv
# site-packages.astropy.io.ascii.tests.test_fixedwidth
# site-packages.astropy.io.ascii.tests.test_html
# site-packages.astropy.io.ascii.tests.test_ipac_definitions
# site-packages.astropy.io.ascii.tests.test_read
# site-packages.astropy.io.ascii.tests.test_rst
# site-packages.astropy.io.ascii.tests.test_types
# site-packages.astropy.io.ascii.tests.test_write
# site-packages.astropy.io.fits.card
# site-packages.astropy.io.fits.column
# site-packages.astropy.io.fits.connect
# site-packages.astropy.io.fits.convenience
# site-packages.astropy.io.fits.diff
# site-packages.astropy.io.fits.file
# site-packages.astropy.io.fits.fitsrec
# site-packages.astropy.io.fits.fitstime
# site-packages.astropy.io.fits.header
# site-packages.astropy.io.fits.setup_package
# site-packages.astropy.io.fits.util
# site-packages.astropy.io.fits.verify
# site-packages.astropy.io.fits.hdu.base
# site-packages.astropy.io.fits.hdu.compressed
# site-packages.astropy.io.fits.hdu.groups
# site-packages.astropy.io.fits.hdu.hdulist
# site-packages.astropy.io.fits.hdu.image
# site-packages.astropy.io.fits.hdu.nonstandard
# site-packages.astropy.io.fits.hdu.streaming
# site-packages.astropy.io.fits.hdu.table
# site-packages.astropy.io.fits.scripts.fitscheck
# site-packages.astropy.io.fits.scripts.fitsdiff
# site-packages.astropy.io.fits.scripts.fitsheader
# site-packages.astropy.io.fits.scripts.fitsinfo
# site-packages.astropy.io.fits.tests.test_checksum
# site-packages.astropy.io.fits.tests.test_compression_failures
# site-packages.astropy.io.fits.tests.test_connect
# site-packages.astropy.io.fits.tests.test_convenience
# site-packages.astropy.io.fits.tests.test_core
# site-packages.astropy.io.fits.tests.test_diff
# site-packages.astropy.io.fits.tests.test_division
# site-packages.astropy.io.fits.tests.test_fitscheck
# site-packages.astropy.io.fits.tests.test_fitsdiff
# site-packages.astropy.io.fits.tests.test_fitsheader
# site-packages.astropy.io.fits.tests.test_fitsinfo
# site-packages.astropy.io.fits.tests.test_fitstime
# site-packages.astropy.io.fits.tests.test_groups
# site-packages.astropy.io.fits.tests.test_hdulist
# site-packages.astropy.io.fits.tests.test_header
# site-packages.astropy.io.fits.tests.test_image
# site-packages.astropy.io.fits.tests.test_nonstandard
# site-packages.astropy.io.fits.tests.test_structured
# site-packages.astropy.io.fits.tests.test_table
# site-packages.astropy.io.fits.tests.test_uint
# site-packages.astropy.io.fits.tests.test_util
# site-packages.astropy.io.misc.connect
# site-packages.astropy.io.misc.hdf5
# site-packages.astropy.io.misc.pickle_helpers
# site-packages.astropy.io.misc.yaml
# site-packages.astropy.io.misc.asdf.connect
# site-packages.astropy.io.misc.asdf.extension
# site-packages.astropy.io.misc.asdf.types
# site-packages.astropy.io.misc.asdf.tags.helpers
# site-packages.astropy.io.misc.asdf.tags.coordinates.angle
# site-packages.astropy.io.misc.asdf.tags.coordinates.earthlocation
# site-packages.astropy.io.misc.asdf.tags.coordinates.frames
# site-packages.astropy.io.misc.asdf.tags.coordinates.representation
# site-packages.astropy.io.misc.asdf.tags.coordinates.skycoord
# site-packages.astropy.io.misc.asdf.tags.coordinates.tests.test_angle
# site-packages.astropy.io.misc.asdf.tags.coordinates.tests.test_earthlocation
# site-packages.astropy.io.misc.asdf.tags.coordinates.tests.test_frames
# site-packages.astropy.io.misc.asdf.tags.coordinates.tests.test_representation
# site-packages.astropy.io.misc.asdf.tags.coordinates.tests.test_skycoord
# site-packages.astropy.io.misc.asdf.tags.fits.fits
# site-packages.astropy.io.misc.asdf.tags.fits.tests.test_fits
# site-packages.astropy.io.misc.asdf.tags.table.table
# site-packages.astropy.io.misc.asdf.tags.table.tests.test_table
# site-packages.astropy.io.misc.asdf.tags.tests.helpers
# site-packages.astropy.io.misc.asdf.tags.time.time
# site-packages.astropy.io.misc.asdf.tags.time.timedelta
# site-packages.astropy.io.misc.asdf.tags.time.tests.test_time
# site-packages.astropy.io.misc.asdf.tags.time.tests.test_timedelta
# site-packages.astropy.io.misc.asdf.tags.transform.basic
# site-packages.astropy.io.misc.asdf.tags.transform.compound
# site-packages.astropy.io.misc.asdf.tags.transform.math
# site-packages.astropy.io.misc.asdf.tags.transform.polynomial
# site-packages.astropy.io.misc.asdf.tags.transform.projections
# site-packages.astropy.io.misc.asdf.tags.transform.tabular
# site-packages.astropy.io.misc.asdf.tags.transform.tests.test_transform
# site-packages.astropy.io.misc.asdf.tags.unit.equivalency
# site-packages.astropy.io.misc.asdf.tags.unit.quantity
# site-packages.astropy.io.misc.asdf.tags.unit.unit
# site-packages.astropy.io.misc.asdf.tags.unit.tests.test_equivalency
# site-packages.astropy.io.misc.asdf.tags.unit.tests.test_quantity
# site-packages.astropy.io.misc.asdf.tags.unit.tests.test_unit
# site-packages.astropy.io.misc.asdf.tests.test_io
# site-packages.astropy.io.misc.pandas.connect
# site-packages.astropy.io.misc.tests.test_hdf5
# site-packages.astropy.io.misc.tests.test_pandas
# site-packages.astropy.io.misc.tests.test_pickle_helpers
# site-packages.astropy.io.misc.tests.test_yaml
# site-packages.astropy.io.tests.test_registry
# site-packages.astropy.io.tests.test_registry_help
# site-packages.astropy.io.votable.connect
# site-packages.astropy.io.votable.converters
# site-packages.astropy.io.votable.exceptions
# site-packages.astropy.io.votable.setup_package
# site-packages.astropy.io.votable.table
# site-packages.astropy.io.votable.tree
# site-packages.astropy.io.votable.ucd
# site-packages.astropy.io.votable.util
# site-packages.astropy.io.votable.volint
# site-packages.astropy.io.votable.xmlutil
# site-packages.astropy.io.votable.tests.converter_test
# site-packages.astropy.io.votable.tests.exception_test
# site-packages.astropy.io.votable.tests.resource_test
# site-packages.astropy.io.votable.tests.table_test
# site-packages.astropy.io.votable.tests.tree_test
# site-packages.astropy.io.votable.tests.ucd_test
# ...
# site-packages.winpty.winpty_wrapper
# site-packages.winpty.tests.test_cywinpty
# site-packages.winpty.tests.test_ptyprocess
# site-packages.winpty.tests.test_winpty_wrapper
# site-packages.win_unicode_console.buffer
# site-packages.win_unicode_console.console
# site-packages.win_unicode_console.file_object
# site-packages.win_unicode_console.info
# site-packages.win_unicode_console.raw_input
# site-packages.win_unicode_console.readline_hook
# site-packages.win_unicode_console.runner
# site-packages.win_unicode_console.streams
# site-packages.win_unicode_console.tokenize_open
# site-packages.win_unicode_console.unicode_argv
# site-packages.wrapt.decorators
# site-packages.wrapt.importer
# site-packages.wrapt.wrappers
# site-packages.xlrd.biffh
# site-packages.xlrd.book
# site-packages.xlrd.compdoc
# site-packages.xlrd.formatting
# site-packages.xlrd.formula
# site-packages.xlrd.info
# site-packages.xlrd.sheet
# site-packages.xlrd.timemachine
# site-packages.xlrd.xldate
# site-packages.xlrd.xlsx
# site-packages.xlsxwriter.app
# site-packages.xlsxwriter.chart
# site-packages.xlsxwriter.chartsheet
# site-packages.xlsxwriter.chart_area
# site-packages.xlsxwriter.chart_bar
# site-packages.xlsxwriter.chart_column
# site-packages.xlsxwriter.chart_doughnut
# site-packages.xlsxwriter.chart_line
# site-packages.xlsxwriter.chart_pie
# site-packages.xlsxwriter.chart_radar
# site-packages.xlsxwriter.chart_scatter
# site-packages.xlsxwriter.chart_stock
# site-packages.xlsxwriter.comments
# site-packages.xlsxwriter.compatibility
# site-packages.xlsxwriter.contenttypes
# site-packages.xlsxwriter.core
# site-packages.xlsxwriter.custom
# site-packages.xlsxwriter.drawing
# site-packages.xlsxwriter.exceptions
# site-packages.xlsxwriter.format
# site-packages.xlsxwriter.packager
# site-packages.xlsxwriter.relationships
# site-packages.xlsxwriter.shape
# site-packages.xlsxwriter.sharedstrings
# site-packages.xlsxwriter.styles
# site-packages.xlsxwriter.table
# site-packages.xlsxwriter.theme
# site-packages.xlsxwriter.utility
# site-packages.xlsxwriter.vml
# site-packages.xlsxwriter.workbook
# site-packages.xlsxwriter.worksheet
# site-packages.xlsxwriter.xmlwriter
# site-packages.xlwings.cli
# site-packages.xlwings.constants
# site-packages.xlwings.expansion
# site-packages.xlwings.mac_dict
# site-packages.xlwings.main
# site-packages.xlwings.server
# site-packages.xlwings.udfs
# site-packages.xlwings.utils
# site-packages.xlwings._xlmac
# site-packages.xlwings._xlwindows
# site-packages.xlwings.conversion.framework
# site-packages.xlwings.conversion.numpy_conv
# site-packages.xlwings.conversion.pandas_conv
# site-packages.xlwings.conversion.standard
# site-packages.xlwings.ext.sql
# site-packages.xlwings.pro.embedded_code
# site-packages.xlwings.pro.utils
# site-packages.xlwings.pro.reports.main
# site-packages.xlwings.rest.api
# site-packages.xlwings.rest.serializers
# site-packages.xlwt.antlr
# site-packages.xlwt.BIFFRecords
# site-packages.xlwt.Bitmap
# site-packages.xlwt.Cell
# site-packages.xlwt.Column
# site-packages.xlwt.compat
# site-packages.xlwt.CompoundDoc
# site-packages.xlwt.ExcelFormula
# site-packages.xlwt.ExcelFormulaLexer
# site-packages.xlwt.ExcelFormulaParser
# site-packages.xlwt.ExcelMagic
# site-packages.xlwt.Formatting
# site-packages.xlwt.Row
# site-packages.xlwt.Style
# site-packages.xlwt.UnicodeUtils
# site-packages.xlwt.Utils
# site-packages.xlwt.Workbook
# site-packages.xlwt.Worksheet
# site-packages.yaml.composer
# site-packages.yaml.constructor
# site-packages.yaml.cyaml
# site-packages.yaml.dumper
# site-packages.yaml.emitter
# site-packages.yaml.error
# site-packages.yaml.events
# site-packages.yaml.loader
# site-packages.yaml.nodes
# site-packages.yaml.parser
# site-packages.yaml.reader
# site-packages.yaml.representer
# site-packages.yaml.resolver
# site-packages.yaml.scanner
# site-packages.yaml.serializer
# site-packages.yaml.tokens
# site-packages.yapf.__main__
# site-packages.yapf.yapflib.blank_line_calculator
# site-packages.yapf.yapflib.comment_splicer
# site-packages.yapf.yapflib.continuation_splicer
# site-packages.yapf.yapflib.errors
# site-packages.yapf.yapflib.file_resources
# site-packages.yapf.yapflib.format_decision_state
# site-packages.yapf.yapflib.format_token
# site-packages.yapf.yapflib.identify_container
# site-packages.yapf.yapflib.line_joiner
# site-packages.yapf.yapflib.object_state
# site-packages.yapf.yapflib.py3compat
# site-packages.yapf.yapflib.pytree_unwrapper
# site-packages.yapf.yapflib.pytree_utils
# site-packages.yapf.yapflib.pytree_visitor
# site-packages.yapf.yapflib.reformatter
# site-packages.yapf.yapflib.split_penalty
# site-packages.yapf.yapflib.style
# site-packages.yapf.yapflib.subtype_assigner
# site-packages.yapf.yapflib.unwrapped_line
# site-packages.yapf.yapflib.verifier
# site-packages.yapf.yapflib.yapf_api
# site-packages.yapftests.blank_line_calculator_test
# site-packages.yapftests.comment_splicer_test
# site-packages.yapftests.file_resources_test
# site-packages.yapftests.format_decision_state_test
# site-packages.yapftests.format_token_test
# site-packages.yapftests.line_joiner_test
# site-packages.yapftests.main_test
# site-packages.yapftests.pytree_unwrapper_test
# site-packages.yapftests.pytree_utils_test
# site-packages.yapftests.pytree_visitor_test
# site-packages.yapftests.reformatter_basic_test
# site-packages.yapftests.reformatter_buganizer_test
# site-packages.yapftests.reformatter_facebook_test
# site-packages.yapftests.reformatter_pep8_test
# site-packages.yapftests.reformatter_python3_test
# site-packages.yapftests.reformatter_style_config_test
# site-packages.yapftests.reformatter_verify_test
# site-packages.yapftests.split_penalty_test
# site-packages.yapftests.style_test
# site-packages.yapftests.subtype_assigner_test
# site-packages.yapftests.unwrapped_line_test
# site-packages.yapftests.utils
# site-packages.yapftests.yapf_test
# site-packages.yapftests.yapf_test_helper
# site-packages.zict.buffer
# site-packages.zict.common
# site-packages.zict.file
# site-packages.zict.func
# site-packages.zict.lmdb
# site-packages.zict.lru
# site-packages.zict.sieve
# site-packages.zict.zip
# site-packages.zmq.decorators
# site-packages.zmq.error
# site-packages.zmq._future
# site-packages.zmq.auth.base
# site-packages.zmq.auth.certs
# site-packages.zmq.auth.ioloop
# site-packages.zmq.auth.thread
# site-packages.zmq.backend.select
# site-packages.zmq.backend.cffi.constants
# site-packages.zmq.backend.cffi.context
# site-packages.zmq.backend.cffi.devices
# site-packages.zmq.backend.cffi.error
# site-packages.zmq.backend.cffi.message
# site-packages.zmq.backend.cffi.socket
# site-packages.zmq.backend.cffi.utils
# site-packages.zmq.backend.cffi._cffi
# site-packages.zmq.backend.cffi._poll
# site-packages.zmq.devices.basedevice
# site-packages.zmq.devices.monitoredqueue
# site-packages.zmq.devices.monitoredqueuedevice
# site-packages.zmq.devices.proxydevice
# site-packages.zmq.devices.proxysteerabledevice
# site-packages.zmq.eventloop.future
# site-packages.zmq.eventloop.ioloop
# site-packages.zmq.eventloop.zmqstream
# site-packages.zmq.eventloop._deprecated
# site-packages.zmq.eventloop.minitornado.concurrent
# site-packages.zmq.eventloop.minitornado.ioloop
# site-packages.zmq.eventloop.minitornado.log
# site-packages.zmq.eventloop.minitornado.stack_context
# site-packages.zmq.eventloop.minitornado.util
# site-packages.zmq.eventloop.minitornado.platform.auto
# site-packages.zmq.eventloop.minitornado.platform.common
# site-packages.zmq.eventloop.minitornado.platform.interface
# site-packages.zmq.eventloop.minitornado.platform.posix
# site-packages.zmq.eventloop.minitornado.platform.windows
# site-packages.zmq.green.core
# site-packages.zmq.green.device
# site-packages.zmq.green.poll
# site-packages.zmq.green.eventloop.ioloop
# site-packages.zmq.green.eventloop.zmqstream
# site-packages.zmq.log.handlers
# site-packages.zmq.log.__main__
# site-packages.zmq.ssh.forward
# site-packages.zmq.ssh.tunnel
# site-packages.zmq.sugar.attrsettr
# site-packages.zmq.sugar.constants
# site-packages.zmq.sugar.context
# site-packages.zmq.sugar.frame
# site-packages.zmq.sugar.poll
# site-packages.zmq.sugar.socket
# site-packages.zmq.sugar.stopwatch
# site-packages.zmq.sugar.tracker
# site-packages.zmq.sugar.version
# site-packages.zmq.tests.conftest
# site-packages.zmq.tests.test_auth
# site-packages.zmq.tests.test_cffi_backend
# site-packages.zmq.tests.test_constants
# site-packages.zmq.tests.test_context
# site-packages.zmq.tests.test_cython
# site-packages.zmq.tests.test_decorators
# site-packages.zmq.tests.test_device
# site-packages.zmq.tests.test_draft
# site-packages.zmq.tests.test_error
# site-packages.zmq.tests.test_etc
# site-packages.zmq.tests.test_future
# site-packages.zmq.tests.test_imports
# site-packages.zmq.tests.test_includes
# site-packages.zmq.tests.test_ioloop
# site-packages.zmq.tests.test_log
# site-packages.zmq.tests.test_message
# site-packages.zmq.tests.test_monitor
# site-packages.zmq.tests.test_monqueue
# site-packages.zmq.tests.test_multipart
# site-packages.zmq.tests.test_pair
# site-packages.zmq.tests.test_poll
# site-packages.zmq.tests.test_proxy_steerable
# site-packages.zmq.tests.test_pubsub
# site-packages.zmq.tests.test_reqrep
# site-packages.zmq.tests.test_retry_eintr
# site-packages.zmq.tests.test_security
# site-packages.zmq.tests.test_socket
# site-packages.zmq.tests.test_ssh
# site-packages.zmq.tests.test_version
# site-packages.zmq.tests.test_win32_shim
# site-packages.zmq.tests.test_z85
# site-packages.zmq.tests.test_zmqstream
# site-packages.zmq.tests.asyncio.test_asyncio
# site-packages.zmq.tests.asyncio._test_asyncio
# site-packages.zmq.utils.constant_names
# site-packages.zmq.utils.garbage
# site-packages.zmq.utils.interop
# site-packages.zmq.utils.jsonapi
# site-packages.zmq.utils.monitor
# site-packages.zmq.utils.sixcerpt
# site-packages.zmq.utils.strtypes
# site-packages.zmq.utils.win32
# site-packages.zmq.utils.z85
# site-packages.zope.event.classhandler
# site-packages.zope.event.tests
# site-packages.zope.interface.adapter
# site-packages.zope.interface.advice
# site-packages.zope.interface.declarations
# site-packages.zope.interface.document
# site-packages.zope.interface.exceptions
# site-packages.zope.interface.interface
# site-packages.zope.interface.interfaces
# site-packages.zope.interface.registry
# site-packages.zope.interface.ro
# site-packages.zope.interface.verify
# site-packages.zope.interface._compat
# site-packages.zope.interface._flatten
# site-packages.zope.interface.common.idatetime
# site-packages.zope.interface.common.interfaces
# site-packages.zope.interface.common.mapping
# site-packages.zope.interface.common.sequence
# site-packages.zope.interface.common.tests.basemapping
# site-packages.zope.interface.common.tests.test_idatetime
# site-packages.zope.interface.common.tests.test_import_interfaces
# site-packages.zope.interface.tests.advisory_testing
# site-packages.zope.interface.tests.dummy
# site-packages.zope.interface.tests.idummy
# site-packages.zope.interface.tests.ifoo
# site-packages.zope.interface.tests.ifoo_other
# site-packages.zope.interface.tests.m1
# site-packages.zope.interface.tests.m2
# site-packages.zope.interface.tests.odd
# site-packages.zope.interface.tests.test_adapter
# site-packages.zope.interface.tests.test_advice
# site-packages.zope.interface.tests.test_declarations
# site-packages.zope.interface.tests.test_document
# site-packages.zope.interface.tests.test_element
# site-packages.zope.interface.tests.test_exceptions
# site-packages.zope.interface.tests.test_interface
# site-packages.zope.interface.tests.test_interfaces
# site-packages.zope.interface.tests.test_odd_declarations
# site-packages.zope.interface.tests.test_registry
# site-packages.zope.interface.tests.test_ro
# site-packages.zope.interface.tests.test_sorting
# site-packages.zope.interface.tests.test_verify
# site-packages._pytest.cacheprovider
# site-packages._pytest.capture
# site-packages._pytest.compat
# site-packages._pytest.debugging
# site-packages._pytest.deprecated
# site-packages._pytest.doctest
# site-packages._pytest.faulthandler
# site-packages._pytest.fixtures
# site-packages._pytest.freeze_support
# site-packages._pytest.helpconfig
# site-packages._pytest.hookspec
# site-packages._pytest.junitxml
# site-packages._pytest.logging
# site-packages._pytest.main
# site-packages._pytest.monkeypatch
# site-packages._pytest.nodes
# site-packages._pytest.nose
# site-packages._pytest.outcomes
# site-packages._pytest.pastebin
# site-packages._pytest.pathlib
# site-packages._pytest.pytester
# site-packages._pytest.python
# site-packages._pytest.python_api
# site-packages._pytest.recwarn
# site-packages._pytest.reports
# site-packages._pytest.resultlog
# site-packages._pytest.runner
# site-packages._pytest.setuponly
# site-packages._pytest.setupplan
# site-packages._pytest.skipping
# site-packages._pytest.stepwise
# site-packages._pytest.store
# site-packages._pytest.terminal
# site-packages._pytest.tmpdir
# site-packages._pytest.unittest
# site-packages._pytest.warnings
# site-packages._pytest.warning_types
# site-packages._pytest._argcomplete
# site-packages._pytest._version
# site-packages._pytest.assertion.rewrite
# site-packages._pytest.assertion.truncate
# site-packages._pytest.assertion.util
# site-packages._pytest.config.argparsing
# site-packages._pytest.config.exceptions
# site-packages._pytest.config.findpaths
# site-packages._pytest.mark.evaluate
# site-packages._pytest.mark.legacy
# site-packages._pytest.mark.structures
# site-packages._pytest._code.code
# site-packages._pytest._code.source
# site-packages._pytest._io.saferepr
# sqlite3.dbapi2
# sqlite3.dump
# sqlite3.test.backup
# sqlite3.test.dbapi
# sqlite3.test.dump
# sqlite3.test.factory
# sqlite3.test.hooks
# sqlite3.test.regression
# sqlite3.test.transactions
# sqlite3.test.types
# sqlite3.test.userfunctions
# test.support.script_helper
# test.support.testresult
# tkinter.colorchooser
# tkinter.commondialog
# tkinter.constants
# tkinter.dialog
# tkinter.dnd
# tkinter.filedialog
# tkinter.font
# tkinter.messagebox
# tkinter.scrolledtext
# tkinter.simpledialog
# tkinter.tix
# tkinter.ttk
# tkinter.__main__
# tkinter.test.runtktests
# tkinter.test.support
# tkinter.test.widget_tests
# tkinter.test.test_tkinter.test_font
# tkinter.test.test_tkinter.test_geometry_managers
# tkinter.test.test_tkinter.test_images
# tkinter.test.test_tkinter.test_loadtk
# tkinter.test.test_tkinter.test_misc
# tkinter.test.test_tkinter.test_text
# tkinter.test.test_tkinter.test_variables
# tkinter.test.test_tkinter.test_widgets
# tkinter.test.test_ttk.test_extensions
# tkinter.test.test_ttk.test_functions
# tkinter.test.test_ttk.test_style
# tkinter.test.test_ttk.test_widgets
# turtledemo.bytedesign
# turtledemo.chaos
# turtledemo.clock
# turtledemo.colormixer
# turtledemo.forest
# turtledemo.fractalcurves
# turtledemo.lindenmayer
# turtledemo.minimal_hanoi
# turtledemo.nim
# turtledemo.paint
# turtledemo.peace
# turtledemo.penrose
# turtledemo.planet_and_moon
# turtledemo.rosette
# turtledemo.round_dance
# turtledemo.sorting_animate
# turtledemo.tree
# turtledemo.two_canvases
# turtledemo.yinyang
# turtledemo.__main__
# unittest.async_case
# unittest.case
# unittest.loader
# unittest.main
# unittest.mock
# unittest.result
# unittest.runner
# unittest.signals
# unittest.suite
# unittest.util
# unittest.__main__
# unittest.test.dummy
# unittest.test.support
# unittest.test.test_assertions
# unittest.test.test_async_case
# unittest.test.test_break
# unittest.test.test_case
# unittest.test.test_discovery
# unittest.test.test_functiontestcase
# unittest.test.test_loader
# unittest.test.test_program
# unittest.test.test_result
# unittest.test.test_runner
# unittest.test.test_setups
# unittest.test.test_skipping
# unittest.test.test_suite
# unittest.test._test_warnings
# unittest.test.__main__
# unittest.test.testmock.support
# unittest.test.testmock.testasync
# unittest.test.testmock.testcallable
# unittest.test.testmock.testhelpers
# unittest.test.testmock.testmagicmethods
# unittest.test.testmock.testmock
# unittest.test.testmock.testpatch
# unittest.test.testmock.testsealable
# unittest.test.testmock.testsentinel
# unittest.test.testmock.testwith
# unittest.test.testmock.__main__
# urllib.error
# urllib.parse
# urllib.request
# urllib.response
# urllib.robotparser
# venv.__main__
# wsgiref.handlers
# wsgiref.headers
# wsgiref.simple_server
# wsgiref.util
# wsgiref.validate
# xml.dom.domreg
# xml.dom.expatbuilder
# xml.dom.minicompat
# xml.dom.minidom
# xml.dom.NodeFilter
# xml.dom.pulldom
# xml.dom.xmlbuilder
# xml.etree.cElementTree
# xml.etree.ElementInclude
# xml.etree.ElementPath
# xml.etree.ElementTree
# xml.parsers.expat
# xml.sax.expatreader
# xml.sax.handler
# xml.sax.saxutils
# xml.sax.xmlreader
# xml.sax._exceptions
# xmlrpc.client
# xmlrpc.server
#
# * Total de módulos instalados: 16215

# %%
def bib_padrao(versao=None, so_nivel_superior=True):
    import re   # módulo da bibl. padrão p/ análise de exprs. regulares
    from urllib.request import urlopen
    if versao is None:
        import sys # outro módulo da bibl. padrão
        versao = sys.version_info
        versao = f"{versao.major}.{versao.minor}"
    url = f"https://docs.python.org/{versao}/py-modindex.html"
    with urlopen(url) as f:
        paginaWeb = f.read()
    modulos = set()
    n = 0
    for modulo in re.findall(r'#module-(.*?)[\'"]',
                             paginaWeb.decode('ascii', 'replace')):
        if so_nivel_superior:
            modulo = modulo.split(".")[0]
        modulos.add(modulo)
        n += 1
    return (modulos,n,versao)

mod, qtd, vs = bib_padrao()
print(f"Qtde de módulos da biblioteca padrão da Ling. Python Vs. {vs}: {qtd}\nMódulos:\n{sorted(mod)}")
# Out:
# Qtde de módulos da biblioteca padrão da Ling. Python Vs. 3.8: 326
# Módulos:
# ['__future__', '__main__', '_dummy_thread', '_thread', 'abc', 'aifc', 'argparse', 'array', 'ast', 'asynchat', 'asyncio', 'asyncore', 'atexit', 'audioop', 'base64', 'bdb', 'binascii', 'binhex', 'bisect', 'builtins', 'bz2', 'cProfile', 'calendar', 'cgi', 'cgitb', 'chunk', 'cmath', 'cmd', 'code', 'codecs', 'codeop', 'collections', 'colorsys', 'compileall', 'concurrent', 'configparser', 'contextlib', 'contextvars', 'copy', 'copyreg', 'crypt', 'csv', 'ctypes', 'curses', 'dataclasses', 'datetime', 'dbm', 'decimal', 'difflib', 'dis', 'distutils', 'doctest', 'dummy_threading', 'email', 'encodings', 'ensurepip', 'enum', 'errno', 'faulthandler', 'fcntl', 'filecmp', 'fileinput', 'fnmatch', 'formatter', 'fractions', 'ftplib', 'functools', 'gc', 'getopt', 'getpass', 'gettext', 'glob', 'grp', 'gzip', 'hashlib', 'heapq', 'hmac', 'html', 'http', 'imaplib', 'imghdr', 'imp', 'importlib', 'inspect', 'io', 'ipaddress', 'itertools', 'json', 'keyword', 'lib2to3', 'linecache', 'locale', 'logging', 'lzma', 'mailbox', 'mailcap', 'marshal', 'math', 'mimetypes', 'mmap', 'modulefinder', 'msilib', 'msvcrt', 'multiprocessing', 'netrc', 'nis', 'nntplib', 'numbers', 'operator', 'optparse', 'os', 'ossaudiodev', 'parser', 'pathlib', 'pdb', 'pickle', 'pickletools', 'pipes', 'pkgutil', 'platform', 'plistlib', 'poplib', 'posix', 'pprint', 'profile', 'pstats', 'pty', 'pwd', 'py_compile', 'pyclbr', 'pydoc', 'queue', 'quopri', 'random', 're', 'readline', 'reprlib', 'resource', 'rlcompleter', 'runpy', 'sched', 'secrets', 'select', 'selectors', 'shelve', 'shlex', 'shutil', 'signal', 'site', 'smtpd', 'smtplib', 'sndhdr', 'socket', 'socketserver', 'spwd', 'sqlite3', 'ssl', 'stat', 'statistics', 'string', 'stringprep', 'struct', 'subprocess', 'sunau', 'symbol', 'symtable', 'sys', 'sysconfig', 'syslog', 'tabnanny', 'tarfile', 'telnetlib', 'tempfile', 'termios', 'test', 'textwrap', 'threading', 'time', 'timeit', 'tkinter', 'token', 'tokenize', 'trace', 'traceback', 'tracemalloc', 'tty', 'turtle', 'turtledemo', 'types', 'typing', 'unicodedata', 'unittest', 'urllib', 'uu', 'uuid', 'venv', 'warnings', 'wave', 'weakref', 'webbrowser', 'winreg', 'winsound', 'wsgiref', 'xdrlib', 'xml', 'xmlrpc', 'zipapp', 'zipfile', 'zipimport', 'zlib']

# %% [markdown]
# Fontes:
# 1. https://www.codigofluente.com.br/aula-19-python-biblioteca-padrao-modulo-math/
# 1. https://www.pythonlikeyoumeanit.com/Module5_OddsAndEnds/WorkingWithFiles.html#Opening-Files
# 1. https://python-course.eu/python-tutorial/file-management.php
